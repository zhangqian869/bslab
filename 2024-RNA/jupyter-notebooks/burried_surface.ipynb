# %%
import numpy as np
import matplotlib.pylab as plt
import scienceplots as sp

# %%
import scipy

# %%
plt.style.use('nature')

# %%
# cases names
# theoA_sc   theoA_cp  theoB_cp
theo= [60.7,65,61.4]

# TAL1A_sc  TAL1A_cp TAL1C_cp
TAL1 = [60.6,63.9,63.3]

# TAL2A_sc  TAL2A_cp  TAL2B_cp
TAL2 = [48.6,68.3,62.4]

# TAL3A_sc TAL3A_cp TAL3B_cp
TAL3 = [46.6,62.6,58.4]

# 7EOK_sc 7EOK_cp
EOK = [62.3894, 64.1219]

# 7EOL_sc 7EOL_cp
EOL = [65.2197, 68.308]

# 7EOM_sc 7EOM_cp
EOM = [65.0095, 67.1665]

# 7EON_sc 7EON_cp
EON = [60.3616, 69.1933]

# 7EOO_sc 7EOO_cp
EOO = [64.8805, 67.6623]

# 7EOP_sc 7EOP_cp
EOP = [62.6738,65.8173]

# %%
plt.figure(figsize=(5,2),dpi=200)
plt.subplot(1,2,1)
plt.bar(np.arange(1,5),[theo[0],TAL1[0],TAL2[0],TAL3[0]],width=0.25,color=['gray','yellowgreen','lime','green'])
plt.bar(np.arange(1,5)+0.27,[theo[1],TAL1[1],TAL2[1],TAL3[1]],width=0.25,color=['gray','yellowgreen','lime','green'],\
         hatch=['//', '//', '//', '//'])
plt.bar(np.arange(1,5)+0.54,[theo[2],TAL1[2],TAL2[2],TAL3[2]],width=0.25,color=['gray','yellowgreen','lime','green'],
       hatch=['oo', 'oo', 'oo', 'oo'],linewidth=0.1)
plt.ylim([40,70])
plt.ylabel("% buriedness")
plt.xticks(np.arange(1,5),['theo A','TAL1 A','TAL2 A','TAL3 A'],rotation=30)
plt.subplot(1,2,2)
plt.bar(np.arange(1,7),[EOK[0],EOL[0],EOM[0],EON[0],EOO[0],EOP[0]],width=0.4,\
       color = ['orangered','orangered','lightsalmon','salmon','darkred','red'])
plt.bar(np.arange(1,7)+0.42,[EOK[1],EOL[1],EOM[1],EON[1],EOO[1],EOP[1]],width=0.4,\
      color = ['orangered','orangered','lightsalmon','salmon','darkred','red'],\
       hatch=['//', '//', '//', '//','//','//'])
plt.xticks(np.arange(1,7),['7EOK','7EOL','7EOM','7EON','7EOO','7EOP'],rotation=30)
plt.ylim([40,70])
plt.yticks([])
plt.subplots_adjust(wspace=0.01)
#plt.ylabel("\% Burried")
