# %%
import numpy as np

import matplotlib.pylab as plt
import scienceplots as sp

# %%
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/Theo/crystalpacking/theoA/charmm-gui-8259072799/gromacs/1D-metaD/"
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/Theo/singleChain/theoB/charmm-gui/gromacs/1D-metaD/"
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/Theo/crystalpacking/theoB/charmm-gui/gromacs/1D-metaD/"
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/Theo/singleChain/TAL1A/charmm-gui-7946633415/gromacs/1D-metaD/"
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/Theo/singleChain/TAL1B/charmmgui/gromacs/1D-metaD/"
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/Theo/singleChain/TAL1C/charmmgui/gromacs/1D-metaD/"
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/Theo/singleChain/TAL1D/charmmgui/gromacs/1D-metaD/"
#roots = '/home/binsun/projects/RNA-small-molecule/analyses/Theo/singleChain/TAL2A/charmm-gui/gromacs/1D-metaD/'
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/Theo/singleChain/TAL2B/charmm-gui-8783752898/gromacs/1D-metaD/"
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/Theo/singleChain/TAL3A/charmm-gui/gromacs/1D-metaD/"
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/Theo/crystalpacking/theoA/charmm-gui-8259072799/gromacs/1D-metaD/"
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/Theo/crystalpacking/theoB/charmm-gui/gromacs/1D-metaD/"
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/Theo/crystalpacking/TAL1A/charmm-gui-8259253493/gromacs/1D-metaD/"
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/Theo/crystalpacking/TAL1C/charmm-gui/gromacs/1D-metaD/"
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/Theo/crystalpacking/TAL2A/charmm-gui-8259357408/gromacs/1D-metaD/"
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/Theo/crystalpacking/TAL2B/charmm-gui-8783947287/gromacs/1D-metaD/"
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/Theo/crystalpacking/TAL3A/charmm-gui-8259502899/gromacs/1D-metaD/"
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/Theo/crystalpacking/TAL3B/charmm-gui/gromacs/1D-metaD/"

# HBC series
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/HBC/singleChain/7EOK/charmm-gui-8353475552/gromacs/1D-metaD/rebindings/"
#roots = '/home/binsun/projects/RNA-small-molecule/analyses/HBC/singleChain/7EOL/charmm-gui-8354479172/gromacs/1D-metaD/rebinding/'
#roots = "/home/bin sun/projects/RNA-small-molecule/analyses/HBC/singleChain/7EOM/charmmgui0000/gromacs/1D-metaD/rebindings/"
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/HBC/singleChain/7EON/charmm-gui-8449517618/gromacs/1D-metaD/rebindings/"
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/HBC/singleChain/7EOO/charmm-gui-8449618985/gromacs/1D-metaD/rebindings/"
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/HBC/singleChain/7EOP/charmm-gui-8456774839/gromacs/1D-metaD/rebindings/"
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/HBC/crystalpacking/7EOK/charmm-gui-8647000415/gromacs/1D-metaD/rebindings/"
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/HBC/crystalpacking/7EOL/charmm-gui-8647165773/gromacs/1D-metaD/rebindings/"
#oots = "/home/binsun/projects/RNA-small-molecule/analyses/HBC/crystalpacking/7EOM/charmm-gui-8653195936/gromacs/1D-metaD/rebindings/"
#oots = "/home/binsun/projects/RNA-small-molecule/analyses/HBC/crystalpacking/7EON/charmm-gui-8653361346/gromacs/1D-metaD/rebindings/"
#roots = "/home/binsun/projects/RNA-small-molecule/analyses/HBC/crystalpacking/7EOO/charmm-gui-8653516965/gromacs/1D-metaD/rebindings/"
roots = "/home/binsun/projects/RNA-small-molecule/analyses/HBC/crystalpacking/7EOP/charmm-gui-8653729703/gromacs/1D-metaD/rebindings/"

# %%
data = [np.loadtxt(roots+"/"+str(i)+"dis.dat",comments="#") for i in np.arange(1,70)]

# %%
n=0
plt.figure(figsize=(8,6),dpi=150)
for i in range(20):
    n += 1
    plt.subplot(4,5,n)
    plt.plot(data[i][:,0],data[i][:,1])
    plt.title(str(n))
    #plt.xlim([0,4000])
    plt.plot([0,20000],[1,1],'r-')

# %%
n=20
plt.figure(figsize=(8,6),dpi=150)
for i in range(20,40):
    n += 1
    plt.subplot(4,5,n-20)
    plt.plot(data[i][:,0],data[i][:,1])
    plt.title(str(n))
    #plt.xlim([0,4000])
    plt.plot([0,20000],[1,1],'r-')

# %%
n=40
plt.figure(figsize=(8,6),dpi=150)
for i in range(40,60):
    n += 1
    plt.subplot(4,5,n-40)
    plt.plot(data[i][:,0],data[i][:,1])
    plt.title(str(n))
   
    plt.plot([0,20000],[1,1],'r-')

# %%
n=60
plt.figure(figsize=(8,6),dpi=150)
for i in range(60,70):
    n += 1
    plt.subplot(2,5,n-60)
    plt.plot(data[i][:,0],data[i][:,1])
    plt.title(str(n))
    plt.xlim([0,4000])
    plt.plot([0,4000],[10,10],'r-')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 6
#       4 n += 1
#       5 plt.subplot(2,5,n-60)
# ----> 6 plt.plot(data[i][:,0],data[i][:,1])
#       7 plt.title(str(n))
#       8 plt.xlim([0,4000])
#
# IndexError: list index out of range

# %%
roots="/home/binsun//projects/RNA-small-molecule/analyses/Theo/singleChain/theoA/charmm-gui-7894634914/gromacs/1D-metaD"

# %%
data = [np.loadtxt(roots+"/"+str(i)+"/dis.dat",comments="#") for i in np.arange(1,71)]

# %%
n=0
plt.figure(figsize=(8,12),dpi=150)
for i in range(60):
    n += 1
    plt.subplot(12,5,n)
    plt.plot(data[i][:,0],data[i][:,1])
    plt.title(str(n))
    plt.xlim([0,4000])
    plt.plot([0,4000],[10,10],'r-')

# %%
plt.figure(figsize=(6,2),dpi=300)
plt.plot(data[6][:,0]/1000,data[6][:,1],lw=0.8,label="replica 7")
plt.plot(data[28][:,0]/1000,data[28][:,1],lw=0.8,label="replica 29")
plt.plot(data[46][:,0]/1000,data[46][:,1],lw=0.8,label="replica 47")
plt.xlabel("Simulation Time (ns)")
plt.ylabel("Ligand distance\n to pocket ($\AA$)")
plt.title("7EOP CP")
plt.legend()

# %%
roots="/home/binsun/projects/RNA-small-molecule/analyses/Theo/singleChain/theoB/charmm-gui/gromacs/1D-metaD/"
theoBdata = [np.loadtxt(roots+"/"+str(i)+"/dis.dat",comments="#") for i in np.arange(1,71)]

# %%
n=0
plt.figure(figsize=(8,12),dpi=150)
for i in range(60):
    n += 1
    plt.subplot(12,5,n)
    plt.plot(theoBdata[i][:,0],theoBdata[i][:,1])
    plt.title(str(n))
    plt.xlim([0,4000])
    plt.plot([0,4000],[10,10],'r-')

# %%
plt.figure(figsize=(6,4),dpi=200)
plt.subplot(2,1,1)
plt.plot(data[47][:,0]/100,data[47][:,1],lw=0.8,label="replica 48")
plt.plot(data[11][:,0]/100,data[11][:,1],lw=0.8,label="replica 12")
plt.plot(data[9][:,0]/100,data[9][:,1],lw=0.8,label="replica 10")
plt.xlabel("Simulation Time (ns)")
plt.ylabel("Ligand distance\n to pocket ($\AA$)")
plt.title("theo A")
plt.legend()
plt.subplot(2,1,2)
plt.plot(theoBdata[1][:,0]/100,theoBdata[1][:,1],lw=0.8,label="replica 2")
plt.plot(theoBdata[13][:,0]/100,theoBdata[13][:,1],lw=0.8,label="replica 14")
plt.plot(theoBdata[31][:,0]/100,theoBdata[31][:,1],lw=0.8,label="replica 32")
plt.xlabel("Simulation Time (ns)")
plt.ylabel("Ligand distance\n to pocket ($\AA$)")
plt.title("theo B")
plt.legend()
plt.subplots_adjust(hspace=0.7)

# %%
plt.style.use('nature')

# %%
# for the theo Seriers single chain, 
# all mg rmsf

allMG= [4.5629,3.4603,3.0248,9.9581,6.1987,4.5455,3.2553,0.9323,1.9229,5.7514,2.9457,2.7369,\
        6.6439,1.9623,3.5837,2.6313,1.3254]
#allMGs = [4.56,  9.96,  6.20,  4.55,  3.26,  1.92,  2.74,  6.64,  0.00,  1.96,  3.58]
allNA = [40.66, 42.39, 41.46, 22.96, 41.28, 35.65, 41.87, 19.98, 39.38, 41.11, 41.93, 36.59, \
         42.38, 34.71, 28.71, 42.58]
allCA = [ 9.55,  9.23,  9.44,  5.91,  3.35]

# %%
plt.figure(figsize=(1.5,2),dpi=200)
plt.bar(np.arange(3),[np.mean(allMG),np.mean(allCA),np.mean(allNA)],\
        yerr=[np.std(allMG),np.std(allCA),np.std(allNA)],\
       color=["lime","yellow",'purple'],ecolor='gray',capsize=2,linewidth=0.1)
plt.ylabel("RMSF ($\AA$)")
plt.xticks([0,1,2],["Mg$^{2+}$","Ca$^{2+}$","Na$^{+}$"])
# Out:
# ([<matplotlib.axis.XTick at 0x78788dc269e0>,
# ...
#  [Text(0, 0, 'Mg$^{2+}$'), Text(1, 0, 'Ca$^{2+}$'), Text(2, 0, 'Na$^{+}$')])

# %%
# the average RMSD of RNA
theoRMSD = np.loadtxt("./rmsdf/singleChainRMSD/theoArmsd")
TAL1ARMSD = np.loadtxt("./rmsdf/singleChainRMSD/TAL1rmsd")
TAL2ARMSD = np.loadtxt("./rmsdf/singleChainRMSD/TAL2rmsd")
TAL3ARMSD = np.loadtxt("./rmsdf/singleChainRMSD/TAL3rmsd")

# %%
plt.figure(figsize=(1.5,2),dpi=200)
plt.bar(np.arange(4),[np.mean(theoRMSD[:,1]),np.mean(TAL1ARMSD[:,1]),\
                      np.mean(TAL2ARMSD[:,1]),np.mean(TAL3ARMSD[:,1])],\
        yerr=[np.std(theoRMSD[:,1]),np.std(TAL1ARMSD[:,1]),np.std(TAL2ARMSD[:,1]),np.std(TAL3ARMSD[:,1])],\
       color=["black","yellowgreen",'lime','green'],ecolor='gray',capsize=2,linewidth=0.1)
plt.xticks([0,1,2,3],["theo A","TAL1 A","TAL2 A","TAL3 A"],rotation=30)
plt.ylabel("RNA RMSD ($\AA$)")
# Out:
# Text(0, 0.5, 'RNA RMSD ($\\AA$)')
