# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %%
#ASPP2 mean

# %%
(-7.25-2.81-5.98-4.42-27.59-4.65-25.52-15.95-12.03-9.16-17.89-4.16-16.37-11.86)/14
# Out:
# -11.831428571428571

# %%
#iASPP mean

# %%
(-2.99-12.38-4.46-2.59-27.89-7.69-4.67-6.47-5.67-6.47-25.64)/11
# Out:
# -9.72

# %%
(-0.97-10.06-4.09-1.73-8.62-22.24-6.32-4.7-10.80-22.84)/10
# Out:
# -9.237

# %%
plt.figure(dpi=300,figsize=(4,3))
#x = np.array([0,20])
#y = np.array([0,20])
datax1 = np.array([-10.40,-10.40,-10.40,-10.40,-10.40,-10.40,-10.40,-10.40,-10.40,-10.40,-10.40,-10.40,-10.40])#ASPP2
datay1 = np.array([-5.35,-4.48,-7.55,-7.31,-23.71,-3.83,-22.34,-11.39,-11.57,-6.67,-15.79,-3.19,-17.53,])
datax2 = np.array([-10.33,-10.33,-10.33,-10.33,-10.33,-10.33,-10.33,-10.33,-10.33,-10.33,-10.33])#iASPP
datay2 = np.array([-0.97,-10.06,-4.09,-1.73,-8.62,-22.24,-6.32,-7.39,-4.7,-10.80,-22.84])
plt.xlabel('Experimental Data',fontsize=14)
plt.ylabel('PMF (kcal/mol)',fontsize=14)
#plt.xticks(np.arange(0,25,5))
#plt.yticks(np.arange(0,35,5))
#plt.title('scatter example')
data_1=plt.plot([0, -20], [-9.67, -9.67], c='b', linestyle='--',linewidth='0.5')
data_2=plt.plot([0, -20], [-9.61, -9.61], c='r', linestyle='--',linewidth='0.5')
plt.scatter(datax1, datay1,color='b',marker='o',s=5,label='ASPP2')
plt.scatter(datax2, datay2,color='r',marker='o',s=5,label='iASPP')
#plt.legend((data_1,data_2), ("ASPP2", "iASPP"), loc = 0)
plt.legend(loc=1,fontsize=7)
plt.xlim([-10.5,-10.2])
#plt.savefig('/home/teliu/work/aspp2/image/scatter.png',bbox_inches='tight',transparent=True)

# %%
pmf_data = [-11.89,-9.67,-12.5,-9.07,-9.61,-8.2,-17.5]
width = 0.7

# %%
plt.figure(figsize=(9,3),dpi=400)
pmf_data = [-11.89,-9.67,-12.5,-9.07,-9.61,-8.2,-17.5]
width = 0.7
labels = ['ASPP2\n(Mean)','Experiment\n(ASPP2)','ASPP2\n(Crysatal)','iASPP\n(Mean)','Experiment\n(iASPP)','iASPP\n(Crysatal)','iASPP\n(1YCS)']
plt.ylabel('Energy(kcal/mol)',fontsize=20)
colors=['r','lime','blue','r','lime','blue','blue']
barlist = plt.bar(labels,pmf_data,width,alpha=0.5)
for i, j in enumerate(barlist):
    j.set_color(colors[i])
plt.bar_label(barlist,padding=3)
plt.ylim([-20,0])
#plt.title('Energy',fontsize=20)
#plt.savefig('/home/teliu/work/2martini/pmf/bar1.png',bbox_inches='tight',transparent=True)

# %%
pmf_data = [-11.89,-9.67,-9.07,-9.61]
width = 0.7

# %%
plt.figure(figsize=(4,3),dpi=400)
labels = ['ASPP2\n(Mean)','Experiment\n(ASPP2)','iASPP\n(Mean)','Experiment\n(iASPP)']
plt.ylabel('Energy(kcal/mol)',fontsize=20)
colors=['r','lime','r','lime']
barlist = plt.bar(labels,pmf_data,width,alpha=0.5)
for i, j in enumerate(barlist):
    j.set_color(colors[i])
plt.bar_label(barlist,padding=3)
plt.ylim([-15,0])
#plt.title('Energy',fontsize=20)
#plt.savefig('/home/teliu/work/2martini/pmf/bar2.png',bbox_inches='tight',transparent=True)

# %%
imap1=np.loadtxt('/home/teliu/work/aspp2/martini/p53/p53-iaspp/result/rmsd-dis/contact7/times.dat',comments="#")
imap2=np.loadtxt('/home/teliu/work/aspp2/martini/p53/p53-iaspp/result/rmsd-dis/contact5/times.dat',comments="#")
imap3=np.loadtxt('/home/teliu/work/aspp2/martini/p53/p53-iaspp/result/rmsd-dis/contact6/times.dat',comments="#")
imap4=np.loadtxt('/home/teliu/work/aspp2/martini/p53/p53-iaspp/result/rmsd-dis/contact8/times.dat',comments="#")
imap5=np.loadtxt('/home/teliu/work/aspp2/martini/p53/p53-iaspp/result/rmsd-dis/contact9/times.dat',comments="#")
imapnmr=np.loadtxt('/home/teliu/work/aspp2/martini/p53/p53-iaspp/result/rmsd-dis/contact7/nmr.dat',comments="#")

# %%
#shiyongdeshuju
plt.figure(figsize=(6,4),dpi=500)
plt.bar(imap1[:,0]+465,imap1[:,1]/10000-0.03,edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='Martini',color='r')
plt.bar(imapnmr[:,0],imapnmr[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='NMR')
plt.ylim([0,0.25])
plt.legend(loc=1,fontsize=7)
plt.title('p53-iASPP')
plt.xlabel('Residues')
plt.ylabel('Contact Probability')
plt.yticks(np.arange(0,0.3,0.05))
#plt.savefig('/home/teliu/work/aspp2/image//iaspp-nmr.png',bbox_inches='tight',transparent=True)
# Out:
# ([<matplotlib.axis.YTick at 0x7f59ce996be0>,
# ...
#  [Text(0, 0.0, '0.00'),
#   Text(0, 0.05, '0.05'),
#   Text(0, 0.1, '0.10'),
#   Text(0, 0.15000000000000002, '0.15'),
#   Text(0, 0.2, '0.20'),
#   Text(0, 0.25, '0.25')])

# %%
plt.figure(figsize=(6,4),dpi=500)
plt.bar(imap2[:,0]+465,imap2[:,1]/10000-0.03,edgecolor='black',linewidth=0.5,width=1,alpha=0.6,label='Martini')
plt.bar(imapnmr[:,0],imapnmr[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.6,label='NMR')
plt.ylim([0,0.25])
plt.legend(loc=1,fontsize=7)
plt.title('p53-iASPP-5')
plt.xlabel('Residues')
#plt.ylabel('Contact Times')
plt.yticks(np.arange(0,0.3,0.05))
#plt.savefig('/home/teliu/Pictures/iaspp-contact.png',bbox_inches='tight',transparent=True)
# Out:
# ([<matplotlib.axis.YTick at 0x7eff65dc08e0>,
# ...
#  [Text(0, 0.0, '0.00'),
#   Text(0, 0.05, '0.05'),
#   Text(0, 0.1, '0.10'),
#   Text(0, 0.15000000000000002, '0.15'),
#   Text(0, 0.2, '0.20'),
#   Text(0, 0.25, '0.25')])

# %%
plt.figure(figsize=(6,4),dpi=500)
plt.bar(imap3[:,0]+465,imap3[:,1]/10000-0.02,edgecolor='black',linewidth=0.5,width=1,alpha=0.6,label='Martini')
plt.bar(imapnmr[:,0],imapnmr[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.6,label='NMR')
plt.legend(loc=1,fontsize=7)
plt.ylim([0,0.25])
plt.title('p53-iASPP-6')
plt.xlabel('Residues')
#plt.ylabel('Contact Times')
plt.yticks(np.arange(0,0.3,0.05))
#plt.savefig('/home/teliu/Pictures/iaspp-contact.png',bbox_inches='tight',transparent=True)
# Out:
# ([<matplotlib.axis.YTick at 0x7f19a4f38640>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(6,4),dpi=500)
plt.bar(imap4[:,0]+465,imap4[:,1]/10000-0.03,edgecolor='black',linewidth=0.5,width=1,alpha=0.6,label='Martini')
plt.bar(imapnmr[:,0],imapnmr[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.6,label='NMR')
plt.legend(loc=1,fontsize=7)
plt.ylim([0,0.25])
plt.title('p53-iASPP-8')
plt.xlabel('Residues')
#plt.ylabel('Contact Times')
plt.yticks(np.arange(0,0.3,0.05))
#plt.savefig('/home/teliu/Pictures/iaspp-contact.png',bbox_inches='tight',transparent=True)
# Out:
# ([<matplotlib.axis.YTick at 0x7f19a4b9beb0>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
amap1=np.loadtxt('/home/teliu/work/aspp2/martini/p53/p53-aspp2/result/dis-rmsd/contact7/times.dat',comments="#")
amap2=np.loadtxt('/home/teliu/work/aspp2/martini/p53/p53-aspp2/result/dis-rmsd/contact5/times.dat',comments="#")
amap3=np.loadtxt('/home/teliu/work/aspp2/martini/p53/p53-aspp2/result/dis-rmsd/contact6/times.dat',comments="#")
amap4=np.loadtxt('/home/teliu/work/aspp2/martini/p53/p53-aspp2/result/dis-rmsd/contact8/times.dat',comments="#")
amapnmr=np.loadtxt('/home/teliu/work/aspp2/martini/p53/p53-aspp2/result/dis-rmsd/contact7/nmr.dat',comments="#")

# %%
#shiyongdeshuju
plt.figure(figsize=(6,4),dpi=500)
plt.bar(amap1[:,0]+734,amap1[:,1]/10000-0.025,edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='Martini',color='red')
plt.bar(amapnmr[:,0],amapnmr[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='NMR')
plt.legend(loc=1,fontsize=7)
plt.ylim([0,0.25])
plt.title('p53-ASPP2')
plt.xlabel('Residues')
plt.ylabel('Contact Probability')
plt.yticks(np.arange(0,0.3,0.05))
#plt.savefig('/home/teliu/work/aspp2/image/aspp2-nmr.png',bbox_inches='tight',transparent=True)
# Out:
# ([<matplotlib.axis.YTick at 0x7f59d8eb7250>,
# ...
#  [Text(0, 0.0, '0.00'),
#   Text(0, 0.05, '0.05'),
#   Text(0, 0.1, '0.10'),
#   Text(0, 0.15000000000000002, '0.15'),
#   Text(0, 0.2, '0.20'),
#   Text(0, 0.25, '0.25')])

# %%
plt.figure(figsize=(6,4),dpi=500)
plt.bar(amap2[:,0]+734,amap2[:,1]/10000,edgecolor='black',linewidth=0.5,width=1,alpha=0.6,label='Martini')
plt.bar(amapnmr[:,0],amapnmr[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.6,label='NMR')
plt.legend(loc=1,fontsize=7)
plt.ylim([0,0.25])
plt.title('p53-ASPP2-5')
plt.xlabel('Residues')
plt.ylabel('Contact Times')
plt.yticks(np.arange(0,0.3,0.05))
#plt.savefig('/home/teliu/Pictures/aspp2-contact.png',bbox_inches='tight',transparent=True)
# Out:
# ([<matplotlib.axis.YTick at 0x7f19a44b2b20>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(6,4),dpi=500)
plt.bar(amap3[:,0]+734,amap3[:,1]/10000,edgecolor='black',linewidth=0.5,width=1,alpha=0.6,label='Martini')
plt.bar(amapnmr[:,0],amapnmr[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.6,label='NMR')
plt.legend(loc=1,fontsize=7)
plt.ylim([0,0.25])
plt.title('p53-ASPP2-6')
plt.xlabel('Residues')
plt.ylabel('Contact Times')
plt.yticks(np.arange(0,0.3,0.05))
#plt.savefig('/home/teliu/Pictures/aspp2-contact.png',bbox_inches='tight',transparent=True)
# Out:
# ([<matplotlib.axis.YTick at 0x7f19a40d8820>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.figure(figsize=(6,4),dpi=500)
plt.bar(amap4[:,0]+734,amap4[:,1]/10000-0.02,edgecolor='black',linewidth=0.5,width=1,alpha=0.6,label='Martini')
plt.bar(amapnmr[:,0],amapnmr[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.6,label='NMR')
plt.legend(loc=1,fontsize=7)
plt.ylim([0,0.25])
plt.title('p53-ASPP2-8')
plt.xlabel('Residues')
plt.ylabel('Contact Times')
plt.yticks(np.arange(0,0.3,0.05))
#plt.savefig('/home/teliu/Pictures/aspp2-contact.png',bbox_inches='tight',transparent=True)
# Out:
# ([<matplotlib.axis.YTick at 0x7f19a3d7b910>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
import os

# %%
wt_tm = np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/mass/11650.dat",comments="#") # 150

# %%
wt_tm = np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/mass/11650.dat",comments="#") # 150
plt.figure(dpi=300,figsize=(2,2))
xs=wt_tm[:,0]
ys=wt_tm[:,1]
plt.scatter(xs, ys, c='r', marker='o',s=2)
plt.plot(xs, ys,c='black',linewidth=0.3,alpha=0.8)

# %%
data = np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/mass/24644.dat",comments="#")
plt.figure(dpi=300,figsize=(2,2))
xs=data[:,0]
ys=data[:,1]
plt.scatter(xs, ys, c='r', marker='o',s=2)
plt.plot(xs, ys,c='black',linewidth=2,alpha=0.8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data = np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/mass/24644.dat",comments="#")
#       2 plt.figure(dpi=300,figsize=(2,2))
#       3 xs=data[:,0]
#
# NameError: name 'np' is not defined

# %%
data = np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/mass/24916.dat",comments="#")
plt.figure(dpi=300,figsize=(2,2))
xs=data[:,0]
ys=data[:,1]
plt.scatter(xs, ys, c='r', marker='o',s=2)
plt.plot(xs, ys,c='black',linewidth=0.3,alpha=0.8)

# %%
plt.figure(dpi=300,figsize=(4,2))
data1=np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/11650/output/result.dat")
data2=np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/11650/output/result1.dat")
data3=np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/11650/output/result2.dat")
data4=np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/11650/output/result3.dat")
data5=np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/11650/output/result4.dat")
plt.plot(data1[:,0],data1[:,1],color='blue',lw=0.1)
plt.fill_between(data1[:,0],data1[:,1]-data1[:,2],data1[:,1]+data1[:,2],color='blue',alpha=0.15,lw=0.1)
plt.plot(data2[:,0],data2[:,1],color='blue',lw=0.1)
plt.fill_between(data2[:,0],data2[:,1]-data2[:,2],data2[:,1]+data2[:,2],color='blue',alpha=0.15,lw=0.1)
plt.plot(data3[:,0],data3[:,1],color='blue',lw=0.1)
plt.fill_between(data3[:,0],data3[:,1]-data3[:,2],data3[:,1]+data3[:,2],color='blue',alpha=0.15,lw=0.1)
plt.plot(data4[:,0],data4[:,1],color='blue',lw=0.1)
plt.fill_between(data4[:,0],data4[:,1]-data4[:,2],data4[:,1]+data4[:,2],color='blue',alpha=0.15,lw=0.1)
plt.plot(data5[:,0],data5[:,1],color='blue',lw=0.1)
plt.fill_between(data5[:,0],data5[:,1]-data5[:,2],data5[:,1]+data5[:,2],color='blue',alpha=0.15,lw=0.1)
#plt.ylim([0,20])
#plt.legend(loc=1,fontsize=7)
plt.xlabel('RC ($\AA$)')
plt.ylabel('PMF (kcal/mol)')
#plt.savefig('/home/teliu/Pictures/p53/p53-aspp2-znnoznpmf1.png',bbox_inches='tight',transparent=True)
# Out:
# Text(0, 0.5, 'PMF (kcal/mol)')

# %%
plt.figure(dpi=300,figsize=(4,2))
data1=np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/24644/output/result.dat")
data2=np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/24644/output/result1.dat")
data3=np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/24644/output/result2.dat")
data4=np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/24644/output/result3.dat")
data5=np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/24644/output/result4.dat")
plt.plot(data1[:,0],data1[:,1],color='blue',lw=0.1)
plt.fill_between(data1[:,0],data1[:,1]-data1[:,2],data1[:,1]+data1[:,2],color='blue',alpha=0.15,lw=0.1)
plt.plot(data2[:,0],data2[:,1],color='blue',lw=0.1)
plt.fill_between(data2[:,0],data2[:,1]-data2[:,2],data2[:,1]+data2[:,2],color='blue',alpha=0.15,lw=0.1)
plt.plot(data3[:,0],data3[:,1],color='blue',lw=0.1)
plt.fill_between(data3[:,0],data3[:,1]-data3[:,2],data3[:,1]+data3[:,2],color='blue',alpha=0.15,lw=0.1)
plt.plot(data4[:,0],data4[:,1],color='blue',lw=0.1)
plt.fill_between(data4[:,0],data4[:,1]-data4[:,2],data4[:,1]+data4[:,2],color='blue',alpha=0.15,lw=0.1)
plt.plot(data5[:,0],data5[:,1],color='blue',lw=0.1)
plt.fill_between(data5[:,0],data5[:,1]-data5[:,2],data5[:,1]+data5[:,2],color='blue',alpha=0.15,lw=0.1)
#plt.ylim([0,20])
#plt.legend(loc=1,fontsize=7)
plt.xlabel('RC ($\AA$)')
plt.ylabel('PMF (kcal/mol)')
#plt.savefig('/home/teliu/Pictures/p53/p53-aspp2-znnoznpmf1.png',bbox_inches='tight',transparent=True)
# Out:
# Text(0, 0.5, 'PMF (kcal/mol)')

# %%
plt.figure(dpi=300,figsize=(4,2))
data1=np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/24916/output/result.dat")
data2=np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/24916/output/result1.dat")
data3=np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/24916/output/result2.dat")
data4=np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/24916/output/result3.dat")
data5=np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/24916/output/result4.dat")
plt.plot(data1[:,0],data1[:,1],color='blue',lw=0.1)
plt.fill_between(data1[:,0],data1[:,1]-data1[:,2],data1[:,1]+data1[:,2],color='blue',alpha=0.15,lw=0.1)
plt.plot(data2[:,0],data2[:,1],color='blue',lw=0.1)
plt.fill_between(data2[:,0],data2[:,1]-data2[:,2],data2[:,1]+data2[:,2],color='blue',alpha=0.15,lw=0.1)
plt.plot(data3[:,0],data3[:,1],color='blue',lw=0.1)
plt.fill_between(data3[:,0],data3[:,1]-data3[:,2],data3[:,1]+data3[:,2],color='blue',alpha=0.15,lw=0.1)
plt.plot(data4[:,0],data4[:,1],color='blue',lw=0.1)
plt.fill_between(data4[:,0],data4[:,1]-data4[:,2],data4[:,1]+data4[:,2],color='blue',alpha=0.15,lw=0.1)
plt.plot(data5[:,0],data5[:,1],color='blue',lw=0.1)
plt.fill_between(data5[:,0],data5[:,1]-data5[:,2],data5[:,1]+data5[:,2],color='blue',alpha=0.15,lw=0.1)
#plt.ylim([0,20])
#plt.legend(loc=1,fontsize=7)
plt.xlabel('RC ($\AA$)')
plt.ylabel('PMF (kcal/mol)')
#plt.savefig('/home/teliu/Pictures/p53/p53-aspp2-znnoznpmf1.png',bbox_inches='tight',transparent=True)
# Out:
# Text(0, 0.5, 'PMF (kcal/mol)')

# %%
from matplotlib import rcParams
rcParams['axes.grid'] = True
plt.figure(dpi=300,figsize=(4,2))
data1=np.loadtxt("/home/teliu/work/aspp2/amber/pmf/p53-aspp2-zn-pmf/output/result.dat")
data2=np.loadtxt("/home/teliu/work/aspp2/amber/pmf/p53-iaspp-zn-pmf/output1/result.dat")
data3=np.loadtxt("/home/teliu/work/aspp2/amber/pmf/p53-iaspp-1ycs-zn-pmf/output/result.dat")
plt.plot(data1[:,0]-34.5,data1[:,1],color='blue',label='p53-ASPP2',lw=0.1)
plt.fill_between(data1[:,0]-34.5,data1[:,1]-data1[:,2],data1[:,1]+data1[:,2],color='blue',alpha=0.3,lw=1.5)
plt.plot(data2[:,0]-27,data2[:,1],color='red',label='p53-iASPP',lw=0.1)
plt.fill_between(data2[:,0]-27,data2[:,1]-data2[:,2],data2[:,1]+data2[:,2],color='red',alpha=0.3,lw=1.5)
plt.plot(data3[:,0]-37.5,data3[:,1],color='green',label='p53-iASPP-1ycs',lw=0.1)
plt.fill_between(data3[:,0]-37.5,data3[:,1]-data3[:,2],data3[:,1]+data3[:,2],color='green',alpha=0.3,lw=1.5)
data_1=plt.plot([0, 15], [9.67, 9.67], c='b', linestyle='--',linewidth='0.5')
data_2=plt.plot([0, 15], [9.61, 9.61], c='red', linestyle='--',linewidth='0.5')
plt.ylim([0,30])
plt.xlim([0,15])
plt.legend(loc=1,fontsize=6)
plt.xlabel('RC ($\AA$)')
plt.ylabel('PMF (kcal/mol)')
#plt.savefig('/home/teliu/work/aspp2/image/aspp-pmf.png',bbox_inches='tight',transparent=True)

# %%
pp53amap1=np.loadtxt('/home/teliu/work/aspp2/martini/temp/p53/pp53-aspp2/result/dis-rmsd/contact/times.dat',comments="#")
pp53imap1=np.loadtxt('/home/teliu/work/aspp2/martini/temp/p53/pp53-iaspp/result/dis-rmsd/contact/times.dat',comments="#")

# %%
#shiyongdeshuju
plt.figure(figsize=(6,4),dpi=500)
plt.bar(pp53amap1[:,0]+693,pp53amap1[:,1]/10000-0.025,edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='Martini',color='red')
plt.bar(amapnmr[:,0],amapnmr[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='NMR')
plt.legend(loc=1,fontsize=7)
plt.ylim([0,0.25])
plt.title('pp53-ASPP2')
plt.xlabel('Residues')
plt.ylabel('Contact Probability')
plt.yticks(np.arange(0,0.3,0.05))
#plt.savefig('/home/teliu/work/aspp2/image/aspp2-nmr.png',bbox_inches='tight',transparent=True)
# Out:
# ([<matplotlib.axis.YTick at 0x7f59d8aff880>,
# ...
#  [Text(0, 0.0, '0.00'),
#   Text(0, 0.05, '0.05'),
#   Text(0, 0.1, '0.10'),
#   Text(0, 0.15000000000000002, '0.15'),
#   Text(0, 0.2, '0.20'),
#   Text(0, 0.25, '0.25')])

# %%
#shiyongdeshuju
plt.figure(figsize=(6,4),dpi=500)
plt.bar(pp53imap1[:,0]+424,pp53imap1[:,1]/10000-0.03,edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='Martini',color='r')
plt.bar(imapnmr[:,0],imapnmr[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='NMR')
plt.ylim([0,0.25])
plt.legend(loc=1,fontsize=7)
plt.title('pp53-iASPP')
plt.xlabel('Residues')
plt.ylabel('Contact Probability')
plt.yticks(np.arange(0,0.3,0.05))
#plt.savefig('/home/teliu/work/aspp2/image//iaspp-nmr.png',bbox_inches='tight',transparent=True)
# Out:
# ([<matplotlib.axis.YTick at 0x7f59cf975bb0>,
# ...
#  [Text(0, 0.0, '0.00'),
#   Text(0, 0.05, '0.05'),
#   Text(0, 0.1, '0.10'),
#   Text(0, 0.15000000000000002, '0.15'),
#   Text(0, 0.2, '0.20'),
#   Text(0, 0.25, '0.25')])

# %%
pp53lamap1=np.loadtxt('/home/teliu/work/aspp2/martini/p53/pp53l-aspp2/result/dis-rmsd//contact7/times.dat',comments="#")
pp53limap1=np.loadtxt('/home/teliu/work/aspp2/martini/p53/pp53l-iaspp/result/rmsd-dis//contact7/times.dat',comments="#")

# %%
#shiyongdeshuju
plt.figure(figsize=(6,4),dpi=500)
plt.bar(pp53lamap1[:,0]+658,pp53lamap1[:,1]/10000-0.1,edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='Martini',color='red')
plt.bar(amapnmr[:,0],amapnmr[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='NMR')
plt.legend(loc=1,fontsize=7)
plt.ylim([0,0.5])
plt.title('pp53l-ASPP2')
plt.xlabel('Residues')
plt.ylabel('Contact Probability')
#plt.yticks(np.arange(0,0.3,0.05))
#plt.savefig('/home/teliu/work/aspp2/image/aspp2-nmr.png',bbox_inches='tight',transparent=True)
# Out:
# Text(0, 0.5, 'Contact Probability')

# %%
#shiyongdeshuju
plt.figure(figsize=(6,4),dpi=500)
plt.bar(pp53limap1[:,0]+389,pp53limap1[:,1]/10000-0.1,edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='Martini',color='r')
plt.bar(imapnmr[:,0],imapnmr[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='NMR')
plt.ylim([0,0.5])
plt.legend(loc=1,fontsize=7)
plt.title('pp53l-iASPP')
plt.xlabel('Residues')
plt.ylabel('Contact Probability')
#plt.yticks(np.arange(0,0.3,0.05))
#plt.savefig('/home/teliu/work/aspp2/image//iaspp-nmr.png',bbox_inches='tight',transparent=True)
# Out:
# Text(0, 0.5, 'Contact Probability')

# %%
p53amap2=np.loadtxt('/home/teliu/work/aspp2/martini/p53/p53-aspp2/result/dis-rmsd/contact7/times.dat',comments="#")
pp53amap2=np.loadtxt('/home/teliu/work/aspp2/martini/temp/p53/pp53-aspp2/result/dis-rmsd/contact/times.dat',comments="#")
pp53lamap2=np.loadtxt('/home/teliu/work/aspp2/martini/p53/pp53l-aspp2/result/dis-rmsd/contact7/times.dat',comments="#")

# %%
plt.figure(figsize=(6,4),dpi=500)
plt.bar(p53amap2[:,0]+76,p53amap2[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='Martini',color='r')
plt.bar(pp53amap2[:,0]+35,pp53amap2[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='Martini',color='blue')
plt.bar(pp53lamap2[:,0],pp53lamap2[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='Martini',color='green')
#plt.bar(imapnmr[:,0],imapnmr[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='NMR')
#plt.ylim([0,0.5])
plt.legend(loc=1,fontsize=7)
plt.title('p53-ASPP2')
plt.xlabel('Residues')
plt.ylabel('Contact Probability')
# Out:
# Text(0, 0.5, 'Contact Probability')

# %%
pmf12484=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/aspp2/12484/output/result.dat")
pmf17431=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/aspp2/17431/output/result.dat")
pmf18279=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/aspp2/18279/output/result.dat")
pmf18404=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/aspp2/18404/output/result.dat")
pmf23458=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/aspp2/23458/output/result.dat")
pmf23707=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/aspp2/23707/output/result.dat")
#pmf23759=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/aspp2/12484/output/result.dat")
pmf23786=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/aspp2/23786/output/result.dat")
pmf32476=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/aspp2/32476/output/result.dat")
pmf37936=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/aspp2/37936/output/result.dat")
pmf4663=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/aspp2/4663/output/result.dat")
pmf4690=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/aspp2/4690/output/result.dat")
pmf4726=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/aspp2/4726/output/result.dat")
pmf776=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/aspp2/776/output/result.dat")

# %%
plt.figure(dpi=300,figsize=(4,2))
plt.plot(pmf12484[:,0]-25,pmf12484[:,1], label='12484',linewidth=0.5)
plt.plot(pmf17431[:,0]-26,pmf17431[:,1], label='17431',linewidth=0.5)
plt.plot(pmf18279[:,0]-28.5,pmf18279[:,1], label='18279',linewidth=0.5)
plt.plot(pmf18404[:,0]-32,pmf18404[:,1], label='18404',linewidth=0.5)
plt.plot(pmf23707[:,0]-42,pmf23707[:,1], label='23707',linewidth=0.5)
plt.plot(pmf23786[:,0]-44.5,pmf23786[:,1], label='23786',linewidth=0.5)
plt.plot(pmf32476[:,0]-26.5,pmf32476[:,1], label='32476',linewidth=0.5)
plt.plot(pmf37936[:,0]-46,pmf37936[:,1], label='37936',linewidth=0.5)
plt.plot(pmf4663[:,0]-33.5,pmf4663[:,1], label='4663',linewidth=0.5)
plt.plot(pmf4690[:,0]-45,pmf4690[:,1], label='4690',linewidth=0.5)
plt.plot(pmf4726[:,0]-41,pmf4726[:,1], label='4726',linewidth=0.5)
plt.plot(pmf776[:,0]-21.5,pmf776[:,1], label='776',linewidth=0.5)
plt.plot(pmf880[:,0]-21.5,pmf880[:,1], label='880',linewidth=0.5)


#plt.ylim([0,100])
plt.xlim([0,30])
plt.legend(loc=1,fontsize=3)
plt.xlabel('RC ($\AA$)')
plt.ylabel('PMF (kcal/mol)')
#plt.savefig('/home/teliu/work/aspp2/image/pmf/aspp2-true.png',bbox_inches='tight',transparent=True)

# %%
pmf11650=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/11650/output/result.dat")
pmf17685=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/17685/output/result.dat")
pmf18803=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/18803/output/result.dat")
pmf18996=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/18996/output/result.dat")
pmf30269=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/30269/output/result.dat")
pmf30903=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/30903/output/result.dat")
pmf328=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/328/output/result.dat")
pmf40329=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/40329/output/result.dat")
pmf40128=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/40128/output/result.dat")
pmf47411=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/47411/output/result.dat")
pmf39243=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/39243/output/result.dat")

# %%
plt.figure(dpi=300,figsize=(4,2))
plt.plot(pmf11650[:,0]-31,pmf11650[:,1], label='11650',linewidth=0.5)
plt.plot(pmf17685[:,0]-27,pmf17685[:,1], label='17685',linewidth=0.5)
plt.plot(pmf18803[:,0]-30,pmf18803[:,1], label='18803',linewidth=0.5)
plt.plot(pmf18996[:,0]-28,pmf18996[:,1], label='18996',linewidth=0.5)
plt.plot(pmf24916[:,0]-27,pmf24916[:,1], label='24916',linewidth=0.5)
plt.plot(pmf30269[:,0]-35,pmf30269[:,1], label='30269',linewidth=0.5)
plt.plot(pmf328[:,0]-33.5,pmf328[:,1], label='328',linewidth=0.5)
plt.plot(pmf39243[:,0]-29.5,pmf39243[:,1], label='39243',linewidth=0.5)
plt.plot(pmf40128[:,0]-34.5,pmf40128[:,1], label='40128',linewidth=0.5)
plt.plot(pmf40329[:,0]-25.5,pmf40329[:,1], label='40329',linewidth=0.5)
plt.plot(pmf47411[:,0]-22,pmf47411[:,1], label='47411',linewidth=0.5)


#plt.ylim([0,100])
plt.xlim([0,30])
plt.legend(loc=1,fontsize=3)
plt.xlabel('RC ($\AA$)')
plt.ylabel('PMF (kcal/mol)')
#plt.savefig('/home/teliu/work/aspp2/image/pmf/iaspp-true.png',bbox_inches='tight',transparent=True)

# %%
pmf12440=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/aspp2/12440/output/result.dat")
pmf24020=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/aspp2/24020/output/result.dat")
pmf39910=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/aspp2/39910/output/result.dat")
pmf23759=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/aspp2/23759/output/result.dat")
pmf4840=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/aspp2/4840/output/result.dat")
pmf748=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/aspp2/748/output/result.dat")
pmf880=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/aspp2/880/output/result.dat")

# %%
plt.figure(dpi=300,figsize=(4,2))
plt.plot(pmf12440[:,0]-26.5,pmf12440[:,1], label='12440',linewidth=0.5)
plt.plot(pmf23458[:,0]-30.5,pmf23458[:,1], label='23458',linewidth=0.5)
plt.plot(pmf23759[:,0]-29,pmf23759[:,1], label='23759',linewidth=0.5)
plt.plot(pmf24020[:,0]-31,pmf24020[:,1], label='24020',linewidth=0.5)
plt.plot(pmf39910[:,0]-32.5,pmf39910[:,1], label='39910',linewidth=0.5)
plt.plot(pmf4840[:,0]-31,pmf4840[:,1], label='4840',linewidth=0.5)
plt.plot(pmf748[:,0]-23,pmf748[:,1], label='748',linewidth=0.5)

#plt.ylim([0,30])
plt.xlim([0,30])
plt.legend(loc=1,fontsize=3)
plt.xlabel('RC ($\AA$)')
plt.ylabel('PMF (kcal/mol)')
#plt.savefig('/home/teliu/work/aspp2/image/pmf/aspp2-flase.png',bbox_inches='tight',transparent=True)

# %%
pmf11281=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/11281/output/result.dat")
pmf13665=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/13665/output/result.dat")
pmf24408=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/24408/output/result.dat")
pmf24644=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/24644/output/result.dat")
pmf24916=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/24916/output/result.dat")
pmf30598=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/30598/output/result.dat")
#pmf39243=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/39243/output/result.dat")
pmf39964=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/39964/output/result.dat")
pmf5388=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/5388/output/result.dat")
pmf6001=np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/6001/output/result.dat")

# %%
plt.figure(dpi=300,figsize=(4,2))
plt.plot(pmf11281[:,0]-24.5,pmf11281[:,1], label='11281',linewidth=0.5)
plt.plot(pmf13665[:,0]-32,pmf13665[:,1], label='13665',linewidth=0.5)
plt.plot(pmf24408[:,0]-22.5,pmf24408[:,1], label='24408',linewidth=0.5)
plt.plot(pmf24644[:,0]-25,pmf24644[:,1], label='24644',linewidth=0.5)
#plt.plot(pmf24916[:,0]-32,pmf24916[:,1], label='24916',linewidth=0.5)
plt.plot(pmf30598[:,0]-33.5,pmf30598[:,1], label='30598',linewidth=0.5)
plt.plot(pmf30903[:,0]-21,pmf30903[:,1], label='30903',linewidth=0.5)
#plt.plot(pmf39243[:,0]-34.5,pmf39243[:,1], label='39243',linewidth=0.5)
plt.plot(pmf39964[:,0]-26.5,pmf39964[:,1], label='39964',linewidth=0.5)
plt.plot(pmf5388[:,0]-25.5,pmf5388[:,1], label='5388',linewidth=0.5)
plt.plot(pmf6001[:,0]-25,pmf6001[:,1], label='6001',linewidth=0.5)

#plt.ylim([0,30])
plt.xlim([0,30])
plt.legend(loc=1,fontsize=3)
plt.xlabel('RC ($\AA$)')
plt.ylabel('PMF (kcal/mol)')
#plt.savefig('/home/teliu/work/aspp2/image/pmf/iaspp-flase.png',bbox_inches='tight',transparent=True)
