# %%
import matplotlib.pylab as plt
import numpy as np

# %%
plt.figure(figsize=(3,1),dpi=300)
#ASPP1=np.loadtxt("aspp1_only_rmsf.dat")
ASPP2=np.loadtxt("/home/teliu/work/1amber/p53/only-ASPP-test/analysis/rmsdf/aspp2_only_rmsf.dat")
iASPP=np.loadtxt("/home/teliu/work/1amber/p53/only-ASPP-test/analysis/rmsdf/iaspp_only_rmsf.dat")
lw=0.6
#plt.plot(ASPP1[:,0],ASPP1[:,1],'cyan',lw=lw, label='ASPP1')
plt.plot(ASPP2[:,0],ASPP2[:,1],'r',lw=lw, label='ASPP2')
plt.plot(iASPP[:,0],iASPP[:,1],'b',lw=lw, label='iASPP')
plt.ylim([0,12])
plt.legend(loc=1,fontsize=3)
#plt.xlim([100,125])
plt.ylabel('RMSF ($\AA$)',fontsize=10)
plt.yticks(fontsize=5)
plt.xticks(fontsize=5)
#plt.legend(['ASPP1','ASPP2','iASPP'],fontsize=5)
plt.xlabel('Residue Number',fontsize=10)
#plt.savefig('/home/teliu/work/1amber/p53/p53-image/aspp2iaspp-rmsf.png',bbox_inches='tight',transparent=True)

# %% [markdown]
# ####

# %%
#aspp1 = np.loadtxt('aspp1_only_rmsd.dat',comments="#")
aspp2 = np.loadtxt('/home/teliu/work/1amber/p53/only-ASPP-test/analysis/rmsdf/aspp2_only_rmsd.dat',comments="#")
iaspp = np.loadtxt('/home/teliu/work/1amber/p53/only-ASPP-test/analysis/rmsdf/iaspp_only_rmsd.dat',comments="#")
Time_Per_Frame = 0.02 # ns
plt.figure(figsize=(3,1),dpi=300)
#plt.plot(aspp1[:,0]*Time_Per_Frame,aspp1[:,1],color='cyan',linewidth=0.5, label='ASPP1')
plt.plot(aspp2[:,0]*Time_Per_Frame,aspp2[:,1],color='r',linewidth=0.1, label='ASPP2')
plt.plot(iaspp[:,0]*Time_Per_Frame,iaspp[:,1],color='b',linewidth=0.1, label='iASPP')
plt.ylim([0,5])
plt.legend(loc=1,fontsize=3)
plt.xlabel('Simulation Time(ns)',fontsize=10)
plt.ylabel('RMSD($\AA$)',fontsize=10)
plt.yticks(fontsize=5)
plt.xticks(fontsize=5)
#plt.savefig('/home/teliu/work/1amber/p53/p53-image/aspp2iaspp-rmsd.png',bbox_inches='tight',transparent=True)

# %%
aspp1 = np.loadtxt('/home/teliu/work/only-ASPP-test/analysis/rmsdf/rmsd1/aspp1refrmsd.dat',comments="#")
aspp2 = np.loadtxt('/home/teliu/work/only-ASPP-test/analysis/rmsdf/rmsd1/aspp2refrmsd.dat',comments="#")
iaspp = np.loadtxt('/home/teliu/work/only-ASPP-test/analysis/rmsdf/rmsd1/iaspprefrmsd.dat',comments="#")
Time_Per_Frame = 0.2 # ns
plt.figure(figsize=(5,2),dpi=300)
plt.plot(aspp1[:,0]*Time_Per_Frame,aspp1[:,1],color='cyan',linewidth=0.5, label='ASPP1')
plt.plot(aspp2[:,0]*Time_Per_Frame,aspp2[:,1],color='blue',linewidth=0.5, label='ASPP2')
plt.plot(iaspp[:,0]*Time_Per_Frame,iaspp[:,1],color='red',linewidth=0.5, label='iASPP')
plt.ylim([0,5])
plt.legend(loc=1,fontsize=5)
plt.xlabel('Simulation Time(ns)',fontsize=10)
plt.ylabel('Ankyrin repeats\nRMSD($\AA$)',fontsize=10)
plt.savefig('/home/teliu/Pictures/p53/only-aspps-ankyrin-repeats-rmsd.png',bbox_inches='tight')

# %%
aspp1 = np.loadtxt('/home/teliu/work/only-ASPP-test/analysis/rmsdf/rmsd2/3/aspp1helix.dat',comments="#")
aspp2 = np.loadtxt('/home/teliu/work/only-ASPP-test/analysis/rmsdf/rmsd2/3/aspp2helix.dat',comments="#")
iaspp = np.loadtxt('/home/teliu/work/only-ASPP-test/analysis/rmsdf/rmsd2/3/iaspphelix.dat',comments="#")
Time_Per_Frame = 0.2 # ns
plt.figure(figsize=(5,2),dpi=300)
plt.plot(aspp1[:,0]*Time_Per_Frame,aspp1[:,1],color='cyan',linewidth=0.5, label='ASPP1')
plt.plot(aspp2[:,0]*Time_Per_Frame,aspp2[:,1],color='blue',linewidth=0.5, label='ASPP2')
plt.plot(iaspp[:,0]*Time_Per_Frame,iaspp[:,1],color='red',linewidth=0.5, label='iASPP')
plt.ylim([0,4])
plt.legend(loc=1,fontsize=5)
plt.xlabel('Simulation Time(ns)',fontsize=10)
plt.ylabel('helix\nRMSD($\AA$)',fontsize=10)
plt.savefig('/home/teliu/Pictures/p53/only-aspps-helix-rmsd.png',bbox_inches='tight')

# %%
aspp1 = np.loadtxt('/home/teliu/work/only-ASPP-test/analysis/rmsdf/rmsd2/3/aspp1helix.dat',comments="#")
aspp2 = np.loadtxt('/home/teliu/work/only-ASPP-test/analysis/rmsdf/rmsd2/3/aspp2helix.dat',comments="#")
iaspp = np.loadtxt('/home/teliu/work/only-ASPP-test/analysis/rmsdf/rmsd2/3/iaspphelix.dat',comments="#")
Time_Per_Frame = 0.2 # ns
plt.figure(figsize=(7,2),dpi=300)
plt.plot(aspp1[:,0]*Time_Per_Frame,aspp1[:,1],color='cyan',linewidth=0.5)
plt.plot(aspp2[:,0]*Time_Per_Frame,aspp2[:,1],color='blue',linewidth=0.5)
plt.plot(iaspp[:,0]*Time_Per_Frame,iaspp[:,1],color='red',linewidth=0.5)
plt.xlabel('Simulation Time(ns)')
plt.ylabel('helix\nRMSD($\AA$)',fontsize=12)
plt.legend(['ASPP1','ASPP2','iaspp'],fontsize=5)

# %%
np.set_printoptions(suppress=True)

# %%
data1=np.loadtxt('/home/teliu/work/aspp2/amber/only-ASPP-test/ASPP2/rmsd.dat',comments="#")
data2=np.loadtxt('/home/teliu/work/aspp2/amber/only-ASPP-test/ASPP2/all-rmsd.dat',comments="#")
data3=np.loadtxt('/home/teliu/work/aspp2/amber/only-ASPP-test/iaspp/rmsd.dat',comments="#")
data4=np.loadtxt('/home/teliu/work/aspp2/amber/only-ASPP-test/iaspp/all-rmsd.dat',comments="#")

# %%
x1=np.mean(data1,axis=1)
x2=np.mean(data3,axis=1)

# %%
print(x2)
# Out:
# [0.85413333 0.95826667 1.03193333 ... 2.487      2.50933333 2.5122    ]

# %%
std1 = np.std(data1,axis=1)
std2 = np.std(data1,axis=1)

# %%
print(std2)
# Out:
# [0.03647943 0.06801328 0.22153037 ... 0.24124826 0.19911317 0.09889079]

# %%
Time_Per_Frame = 0.2

# %%
print(x1)
# Out:
# [1.02036667 1.4578     1.9336     ... 2.97546667 2.83853333 2.97343333]

# %%
plt.plot(data2[:,0]*0.2,x2)

# %%
plt.figure(figsize=(3,1),dpi=300)
plt.plot(data2[:,0]*0.2,x1,color='red',linewidth=0.5,label='ASPP2')
plt.fill_between(data2[:,0]*0.2,x1-std1,x1+std1,color='red',alpha=0.1,lw=1.5)
plt.plot(data4[:,0]*0.2,x2,color='blue',linewidth=0.5,label='iASPP')
plt.fill_between(data4[:,0]*0.2,x2-std2,x2+std2,color='blue',alpha=0.1,lw=1.5)
plt.ylim([0,6])
plt.legend(loc=1,fontsize=5)
plt.xlabel('Simulation Time(ns)',fontsize=10)
plt.ylabel('RMSD($\AA$)',fontsize=10)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)
#02924
#plt.savefig('/home/teliu/work/aspp2/image/aspp2iaspp-rmsd.png',bbox_inches='tight',transparent=True)

# %%
data5=np.loadtxt('/home/teliu/work/aspp2/amber/only-ASPP-test/ASPP2/rmsf.dat',comments="#")
data6=np.loadtxt('/home/teliu/work/aspp2/amber/only-ASPP-test/ASPP2/all-rmsf.dat',comments="#")
data7=np.loadtxt('/home/teliu/work/aspp2/amber/only-ASPP-test/iaspp/rmsf.dat',comments="#")
data8=np.loadtxt('/home/teliu/work/aspp2/amber/only-ASPP-test/iaspp/all-rmsf.dat',comments="#")

# %%
x3=np.mean(data5,axis=1)
x4=np.mean(data7,axis=1)

# %%
print(x4)
# Out:
# [9.58846667 7.62346667 5.90983333 4.3036     2.899      1.641
#  1.15836667 0.89136667 0.91946667 1.01573333 0.8895     0.83383333
#  1.1061     1.2789     1.31296667 1.26743333 1.2736     1.3381
#  1.09313333 1.0152     1.27446667 1.2329     1.2062     1.473
#  1.63186667 1.63306667 1.69496667 1.17303333 0.95813333 0.86056667
#  1.11943333 1.42116667 2.0251     2.06603333 2.48983333 2.4006
#  1.80333333 1.15286667 0.749      0.6354     0.5807     0.7144
#  0.7163     0.5782     0.61416667 0.80443333 0.7481     0.6538
#  0.5932     0.61343333 0.67643333 0.56803333 0.5378     0.6376
#  0.63356667 0.5639     0.61383333 0.7248     0.76796667 0.77856667
#  0.67923333 0.7557     0.75286667 1.0064     1.20783333 1.72966667
#  2.23876667 2.5726     3.33823333 2.70126667 2.2717     2.36216667
#  1.64136667 1.13403333 1.03223333 1.14386667 0.98563333 0.90546667
#  0.96403333 1.24196667 1.4445     1.09903333 0.99436667 0.8857
# ...

# %%
std3 = np.std(data5,axis=1)
std4 = np.std(data7,axis=1)

# %%
plt.figure(figsize=(3,1),dpi=300)
plt.plot(data6[:,0],x3,color='red',linewidth=0.5,label='ASPP2')
plt.fill_between(data6[:,0],x3-std3,x3+std3,color='red',alpha=0.1,lw=1.5)
plt.plot(data8[:,0]+30,x4,color='blue',linewidth=0.5,label='iASPP')
plt.fill_between(data8[:,0]+30,x4-std4,x4+std4,color='blue',alpha=0.1,lw=1.5)
plt.ylim([0,10])
plt.legend(loc=1,fontsize=5)
plt.ylabel('RMSF ($\AA$)',fontsize=10)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)
plt.xlabel('Residue Number',fontsize=10)
#plt.xlim([120,130])
#plt.savefig('/home/teliu/work/aspp2/image/aspp2iaspp-rmsf.png',bbox_inches='tight',transparent=True)

# %%
#aspp2

# %%
e1=np.loadtxt('/home/teliu/work/aspp2/martini/temp/new/pp53l-aspp2/result/encounter-rmsd/run4-rmsd.dat',comments="#")
e2=np.loadtxt('/home/teliu/work/aspp2/martini/temp/new/pp53l-aspp2/result/encounter-rmsd/run13-rmsd.dat',comments="#")
e3=np.loadtxt('/home/teliu/work/aspp2/martini/temp/new/pp53l-aspp2/result/encounter-rmsd/run27-rmsd.dat',comments="#")
e4=np.loadtxt('/home/teliu/work/aspp2/martini/temp/new/pp53l-aspp2/result/encounter-rmsd/run36-rmsd.dat',comments="#")
e5=np.loadtxt('/home/teliu/work/aspp2/martini/temp/new/pp53l-aspp2/result/encounter-rmsd/run44-rmsd.dat',comments="#")
con=np.loadtxt('/home/teliu/work/aspp2/martini/temp/new/pp53l-aspp2/result/encounter-rmsd/rmsdcontact',comments="#")
con1=np.loadtxt('/home/teliu/work/aspp2/martini/temp/new/pp53l-iaspp/result/encounter-rmsd/rmsdcontact',comments="#")

# %%
plt.figure(figsize=(3,2),dpi=300)
plt.plot(e1[:,0]*4,e1[:,1],color='#55B7E6',linewidth=0.5,alpha=0.7)
plt.plot(e2[:,0]*4,e2[:,1],color='#193E8F',linewidth=0.5,alpha=0.7)
plt.plot(e3[:,0]*4,e3[:,1],color='#E53528',linewidth=0.5,alpha=0.7)
plt.plot(e4[:,0]*4,e4[:,1],color='#f09739',linewidth=0.5,alpha=0.7)
plt.plot(e5[:,0]*4,e5[:,1],color='yellow',linewidth=0.5,alpha=0.7)
plt.ylim([0,100])
#plt.legend(loc=1,fontsize=5)
plt.xlabel('Simulation Time(ns)',fontsize=10)
plt.ylabel('RMSD($\AA$)',fontsize=10)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)

#plt.savefig('/home/teliu/work/aspp2/image/xiu/aall-rmsd.png',bbox_inches='tight',transparent=True)
# Out:
# (array([-1000.,     0.,  1000.,  2000.,  3000.,  4000.,  5000.]),
#  [Text(-1000.0, 0, '−1000'),
#   Text(0.0, 0, '0'),
#   Text(1000.0, 0, '1000'),
#   Text(2000.0, 0, '2000'),
#   Text(3000.0, 0, '3000'),
#   Text(4000.0, 0, '4000'),
#   Text(5000.0, 0, '5000')])

# %%
plt.figure(figsize=(3,1),dpi=300)
plt.plot(e1[:,0]*4,e1[:,1],color='blue',linewidth=0.5)
plt.ylim([0,100])
plt.xlim([0,4000])
plt.xlabel('Simulation Time (ns)',fontsize=10)
plt.ylabel('RMSD ($\AA$)',fontsize=10)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)

#plt.savefig('/home/teliu/work/aspp2/image/xiu/a1-rmsd.png',bbox_inches='tight',transparent=True)

# %%
#p53-aspp2-4
fig,ax=plt.subplots(1,1,figsize=(3,1),dpi=300)
ax.plot((e1[:,0]+130)*4,e1[:,1],linewidth=0.5,label='RMSD',color='blue')
ax.set_ylabel('RMSD ($\AA$)')
ax.set_xlabel('Simulation Time (ns)',fontsize=10)
ax.set_ylim(0,250)
ax.set_yticks(range(0,250,100))
ax.set_yticklabels(range(0,250,100),fontsize=10)

ax2 = ax.twinx()
ax.plot(con[:,0],con[:,1],linewidth=0.5,label='Contacts',color='green')
#ax.errorbar(bi[:,0]+424,bi[:,1]/200,yerr=bi[:,2]/200,elinewidth=0.3,capsize=1,capthick=0.4,lw=0,color='black')
#plt.ylim(0,0.25)
ax2.set_ylabel('Contacts')
ax2.set_ylim(0,250)
ax2.set_yticks(range(0,250,100))
ax2.set_yticklabels(range(0,250,100),fontsize=10)

ax.legend(loc=1,fontsize=6)
#plt.title('pp53-iASPP')
#plt.savefig('/home/teliu/work/aspp2/image/xiu/rmsd-contact.png',bbox_inches='tight',transparent=True)

# %%
#p53-iaspp-4
fig,ax=plt.subplots(1,1,figsize=(3,1),dpi=300)
ax.plot((e6[:,0]+95)*4,e6[:,1],linewidth=0.5,label='RMSD',color='red')
ax.set_ylabel('RMSD ($\AA$)')
ax.set_xlabel('Simulation Time (ns)',fontsize=10)
ax.set_ylim(0,250)
ax.set_yticks(range(0,250,100))
ax.set_yticklabels(range(0,250,100),fontsize=10)

ax2 = ax.twinx()
ax.plot(con1[:,0],con1[:,1],linewidth=0.5,label='Contacts',color='green')
#ax.errorbar(bi[:,0]+424,bi[:,1]/200,yerr=bi[:,2]/200,elinewidth=0.3,capsize=1,capthick=0.4,lw=0,color='black')
#plt.ylim(0,0.25)
ax2.set_ylabel('Contacts')
ax2.set_ylim(0,250)
ax2.set_yticks(range(0,250,100))
ax2.set_yticklabels(range(0,250,100),fontsize=10)

ax.legend(loc=1,fontsize=6)
#plt.title('pp53-iASPP')
#plt.savefig('/home/teliu/work/aspp2/image/xiu/rmsd-contact1.png',bbox_inches='tight',transparent=True)

# %%
plt.figure(figsize=(3,1),dpi=300)
plt.plot(e2[:,0]*4,e2[:,1],color='blue',linewidth=0.5)
plt.ylim([0,100])
plt.xlim([0,4000])
plt.xlabel('Simulation Time (ns)',fontsize=10)
plt.ylabel('RMSD ($\AA$)',fontsize=10)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)

#plt.savefig('/home/teliu/work/aspp2/image/xiu/a2-rmsd.png',bbox_inches='tight',transparent=True)

# %%
plt.figure(figsize=(3,1),dpi=300)
plt.plot(e3[:,0]*4,e3[:,1],color='blue',linewidth=0.5)
plt.ylim([0,100])
plt.xlim([0,4000])
plt.xlabel('Simulation Time (ns)',fontsize=10)
plt.ylabel('RMSD ($\AA$)',fontsize=10)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)

#plt.savefig('/home/teliu/work/aspp2/image/xiu/a3-rmsd.png',bbox_inches='tight',transparent=True)

# %%
plt.figure(figsize=(3,1),dpi=300)
plt.plot(e4[:,0]*4,e4[:,1],color='blue',linewidth=0.5)
plt.ylim([0,100])
plt.xlim([0,4000])
plt.xlabel('Simulation Time (ns)',fontsize=10)
plt.ylabel('RMSD ($\AA$)',fontsize=10)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)

#plt.savefig('/home/teliu/work/aspp2/image/xiu/a4-rmsd.png',bbox_inches='tight',transparent=True)

# %%
plt.figure(figsize=(3,1),dpi=300)
plt.plot(e5[:,0]*4,e5[:,1],color='blue',linewidth=0.5)
plt.ylim([0,100])
plt.xlim([0,4000])
plt.xlabel('Simulation Time (ns)',fontsize=10)
plt.ylabel('RMSD ($\AA$)',fontsize=10)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)

#plt.savefig('/home/teliu/work/aspp2/image/xiu/a5-rmsd.png',bbox_inches='tight',transparent=True)

# %%
#iaspp

# %%
e6=np.loadtxt('/home/teliu/work/aspp2/martini/temp/new/pp53l-iaspp/result/encounter-rmsd/run4-rmsd.dat',comments="#")
e7=np.loadtxt('/home/teliu/work/aspp2/martini/temp/new/pp53l-iaspp/result/encounter-rmsd/run13-rmsd.dat',comments="#")
e8=np.loadtxt('/home/teliu/work/aspp2/martini/temp/new/pp53l-iaspp/result/encounter-rmsd/run27-rmsd.dat',comments="#")
e9=np.loadtxt('/home/teliu/work/aspp2/martini/temp/new/pp53l-iaspp/result/encounter-rmsd/run36-rmsd.dat',comments="#")
e10=np.loadtxt('/home/teliu/work/aspp2/martini/temp/new/pp53l-iaspp/result/encounter-rmsd/run45-rmsd.dat',comments="#")

# %%
plt.figure(figsize=(3,2),dpi=300)
plt.plot(e6[:,0]*4,e6[:,1],color='#55B7E6',linewidth=0.5,alpha=0.7)
plt.plot(e7[:,0]*4,e7[:,1],color='#193E8F',linewidth=0.5,alpha=0.7)
plt.plot(e8[:,0]*4,e8[:,1],color='#E53528',linewidth=0.5,alpha=0.7)
plt.plot(e9[:,0]*4,e9[:,1],color='#f09739',linewidth=0.5,alpha=0.7)
plt.plot(e10[:,0]*4,e10[:,1],color='yellow',linewidth=0.5,alpha=0.7)
plt.ylim([0,100])
#plt.legend(loc=1,fontsize=5)
plt.xlabel('Simulation Time(ns)',fontsize=10)
plt.ylabel('RMSD($\AA$)',fontsize=10)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)

#plt.savefig('/home/teliu/work/aspp2/image/xiu/iall-rmsd.png',bbox_inches='tight',transparent=True)
# Out:
# (array([-1000.,     0.,  1000.,  2000.,  3000.,  4000.,  5000.]),
#  [Text(-1000.0, 0, '−1000'),
#   Text(0.0, 0, '0'),
#   Text(1000.0, 0, '1000'),
#   Text(2000.0, 0, '2000'),
#   Text(3000.0, 0, '3000'),
#   Text(4000.0, 0, '4000'),
#   Text(5000.0, 0, '5000')])

# %%
plt.figure(figsize=(3,1),dpi=300)
plt.plot(e6[:,0]*4,e6[:,1],color='red',linewidth=0.5)
plt.ylim([0,100])
plt.xlim([0,4000])
plt.xlabel('Simulation Time (ns)',fontsize=10)
plt.ylabel('RMSD ($\AA$)',fontsize=10)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)

#plt.savefig('/home/teliu/work/aspp2/image/xiu/i6-rmsd.png',bbox_inches='tight',transparent=True)

# %%
plt.figure(figsize=(3,1),dpi=300)
plt.plot(e7[:,0]*4,e7[:,1],color='red',linewidth=0.5)
plt.ylim([0,100])
plt.xlim([0,4000])
plt.xlabel('Simulation Time (ns)',fontsize=10)
plt.ylabel('RMSD ($\AA$)',fontsize=10)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)

#plt.savefig('/home/teliu/work/aspp2/image/xiu/i7-rmsd.png',bbox_inches='tight',transparent=True)

# %%
plt.figure(figsize=(3,1),dpi=300)
plt.plot(e8[:,0]*4,e8[:,1],color='red',linewidth=0.5)
plt.ylim([0,100])
plt.xlim([0,4000])
plt.xlabel('Simulation Time (ns)',fontsize=10)
plt.ylabel('RMSD ($\AA$)',fontsize=10)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)

#plt.savefig('/home/teliu/work/aspp2/image/xiu/i8-rmsd.png',bbox_inches='tight',transparent=True)

# %%
plt.figure(figsize=(3,1),dpi=300)
plt.plot(e9[:,0]*4,e9[:,1],color='red',linewidth=0.5)
plt.ylim([0,100])
plt.xlim([0,4000])
plt.xlabel('Simulation Time (ns)',fontsize=10)
plt.ylabel('RMSD ($\AA$)',fontsize=10)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)

#plt.savefig('/home/teliu/work/aspp2/image/xiu/i9-rmsd.png',bbox_inches='tight',transparent=True)

# %%
plt.figure(figsize=(3,1),dpi=300)
plt.plot(e10[:,0]*4,e10[:,1],color='red',linewidth=0.5)
plt.ylim([0,100])
plt.xlim([0,4000])
plt.xlabel('Simulation Time (ns)',fontsize=10)
plt.ylabel('RMSD ($\AA$)',fontsize=10)
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)

#plt.savefig('/home/teliu/work/aspp2/image/xiu/i10-rmsd.png',bbox_inches='tight',transparent=True)
