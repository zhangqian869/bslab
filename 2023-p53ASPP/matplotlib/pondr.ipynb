# %%
import numpy as np
import matplotlib.pylab as plt

# %%
aspp2=np.loadtxt("/home/teliu/work/aspp2/amber/idp/aspp2.dat")
iaspp=np.loadtxt("/home/teliu/work/aspp2/amber/idp/iaspp.dat")
p53=np.loadtxt("/home/teliu/work/aspp2/amber/idp/p53.dat")
x=np.loadtxt("/home/teliu/work/aspp2/amber/idp/list1")

# %%
plt.figure(dpi=300,figsize=(4,2))
plt.plot(aspp2[:,0],aspp2[:,1],color='r', label='p53-ASPP2',lw=0.5)
data_1=plt.plot([0, 204], [0.5, 0.5], c='black',linewidth='0.5')
plt.title('ASPP2 IDP Prediction')
plt.xlabel('Residues Number')
plt.ylabel('PONDR Score')
#plt.savefig('/home/teliu/work/aspp2/image/aspp2-idp.png',bbox_inches='tight',transparent=True)

# %%
plt.figure(dpi=300,figsize=(4,2))
plt.plot(iaspp[:,0],iaspp[:,1],color='r',lw=0.5)
data_1=plt.plot([0, 204], [0.5, 0.5], c='black',linewidth='0.5')
plt.title('iASPP IDP Prediction')
plt.xlabel('Residues Number')
plt.ylabel('PONDR Score')
#plt.savefig('/home/teliu/work/aspp2/image/iaspp-idp.png',bbox_inches='tight',transparent=True)

# %%
plt.figure(dpi=300,figsize=(4,2))
plt.plot(p53[:,0]+55,p53[:,1],color='r', label='p53-ASPP2',lw=0.5)
data_1=plt.plot([56, 322], [0.5, 0.5], c='black',linewidth='0.5')
#plt.xticks(np.arange(56,289,50))
#plt.xlim([250,270])
plt.title('p53 IDP Prediction')
plt.xlabel('Residues Number')
plt.ylabel('PONDR Score')
#plt.savefig('/home/teliu/work/aspp2/image/p53-idp.png',bbox_inches='tight',transparent=True)
