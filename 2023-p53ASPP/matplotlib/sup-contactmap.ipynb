# %%
import matplotlib.pylab as plt
import numpy as np

# %%
from matplotlib.colors import LinearSegmentedColormap
vmax = 1
cmap = LinearSegmentedColormap.from_list('mycmap',[(0, 'w'),(0.25,'blue'),(0.5, 'lightgreen'),(0.75,'yellow'),(1, 'red')])

# %%
data1 = np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/6001/test/final_results")
data2 = np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/24644/test/final_results")
data3 = np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/24916/test/final_results")
data4 = np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/17685/test/final_results")
data5 = np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/30269/test/final_results")
data6 = np.loadtxt("/home/teliu/work/aspp2/martini/pmf/iaspp/40329/test/final_results")

# %%
data6.shape
# Out:
# (27300,)

# %%
newdata1=data1.reshape((493,-1))

# %%
plt.figure(figsize=(8,4))
plt.title('6001-35.39')
plt.pcolormesh(newdata1,cmap='jet')
fcb = plt.colorbar(plt.cm.ScalarMappable(cmap='jet'))
#7  all atom

# %%
newdata2=data2.reshape((471,-1))

# %%
plt.figure(figsize=(8,4))
plt.title('Contact Map of $\Delta$G=31.54 kcal/mol')
plt.pcolormesh(newdata2,cmap='jet')
fcb = plt.colorbar(plt.cm.ScalarMappable(cmap='jet'))
#plt.savefig('/home/teliu/Pictures/contact-31.54.png',bbox_inches='tight',transparent=True)

# %%
newdata3=data3.reshape((406,-1))

# %%
plt.figure(figsize=(8,4))
plt.title('24916-30.15')
plt.pcolormesh(newdata3,cmap='jet')
fcb = plt.colorbar(plt.cm.ScalarMappable(cmap='jet'))

# %%
newdata4=data4.reshape((369,-1))

# %%
plt.figure(figsize=(8,4))
plt.title('Contact Map of $\Delta$G=10.06 kcal/mol')
plt.pcolormesh(newdata4,cmap='jet')
fcb = plt.colorbar(plt.cm.ScalarMappable(cmap='jet'))
#plt.savefig('/home/teliu/Pictures/contact-10.06.png',bbox_inches='tight',transparent=True)

# %%
newdata5=data5.reshape((395,-1))

# %%
plt.figure(figsize=(8,4))
plt.title('30269-8.62')
plt.pcolormesh(newdata5,cmap='jet')
fcb = plt.colorbar(plt.cm.ScalarMappable(cmap='jet'))

# %%
newdata6=data6.reshape((546,-1))

# %%
plt.figure(figsize=(8,4))
plt.title('40329-10.80')
plt.pcolormesh(newdata6,cmap='jet')
fcb = plt.colorbar(plt.cm.ScalarMappable(cmap='jet'))

# %%
c5data1 = np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/6001/test-c5/final_results")
c5data2 = np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/24644/test-c5/final_results")
c5data3 = np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/24916/test-c5/final_results")
c5data4 = np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/17685/test-c5/final_results")
c5data5 = np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/30269/test-c5/final_results")
c5data6 = np.loadtxt("/home/teliu/work/2martini/pmf/iaspp/40329/test-c5/final_results")

# %%
c5data4.shape
# Out:
# (8200,)

# %%
c5newdata4=c5data4.reshape((164,-1))

# %%
plt.figure(figsize=(8,4))
plt.title('17685-10.06')
plt.pcolormesh(c5newdata4,cmap='jet')
fcb = plt.colorbar(plt.cm.ScalarMappable(cmap='jet'))

# %%
c5data2.shape
# Out:
# (9300,)

# %%
c5newdata2=c5data2.reshape((186,-1))

# %%
plt.figure(figsize=(8,4))
plt.title('24644-31.54')
plt.pcolormesh(c5newdata2,cmap='jet')
fcb = plt.colorbar(plt.cm.ScalarMappable(cmap='jet'))

# %%
c5data5.shape
# Out:
# (8400,)

# %%
c5newdata5=c5data5.reshape((168,-1))

# %%
plt.figure(figsize=(8,4))
plt.title('30269-8.62')
plt.pcolormesh(c5newdata5,cmap='jet')
fcb = plt.colorbar(plt.cm.ScalarMappable(cmap='jet'))

# %%
c5data1.shape
# Out:
# (10900,)

# %%
c5newdata1=c5data1.reshape((218,-1))

# %%
plt.figure(figsize=(8,4))
plt.title('6001-35.39')
plt.pcolormesh(c5newdata1,cmap='jet')
fcb = plt.colorbar(plt.cm.ScalarMappable(cmap='jet'))

# %%
c5data3.shape
# Out:
# (7850,)

# %%
c5newdata3=c5data3.reshape((157,-1))

# %%
plt.figure(figsize=(8,4))
plt.title('24916-30.15')
plt.pcolormesh(c5newdata3,cmap='jet')
fcb = plt.colorbar(plt.cm.ScalarMappable(cmap='jet'))

# %%
c5data6.shape
# Out:
# (11600,)

# %%
c5newdata6=c5data6.reshape((232,-1))

# %%
plt.figure(figsize=(8,4))
plt.title('40329-10.80')
plt.pcolormesh(c5newdata6,cmap='jet')
fcb = plt.colorbar(plt.cm.ScalarMappable(cmap='jet'))
