# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
def list_generator(mean, dis, number):  
    return np.random.normal(mean, dis * dis, number)

# %%
s1 = pd.Series(np.array([-7.25,-2.81,-5.98,-4.42,-4.65,-25.52,-15.95,-12.03,-9.16,-17.89,-4.16,-16.37,-11.86]))
s2 = pd.Series(np.array([-2.99,-12.38,-4.46,-2.59,-7.69,-4.67,-6.47,-5.67,-6.47,-25.64,-27.89]))

# %%
print(np.mean(s1))
print(np.std(s1))
# Out:
# -10.61923076923077
# 6.514402341721187

# %%
print(np.mean(s2))
print(np.std(s2))
# Out:
# -9.72
# 8.42948936229775

# %%
data = pd.DataFrame({"ASPP2": s1, "iASPP": s2})

# %%
plt.figure(dpi=300,figsize=(4,3))
colors=['blue','red']
sns.boxplot( data = data,
           palette=colors,
           linewidth=0.5,
           showmeans=True,
            meanline=True,
            meanprops = {'linestyle':'--','color':'black'})
sns.stripplot( color = 'black',
              size = 7,
              alpha = 0.5,
              data = data)
data_1=plt.plot([-0.5, 1.5], [-9.67, -9.67], c='tab:blue', linestyle='--',linewidth='1')
data_2=plt.plot([-0.5, 1.5], [-9.61, -9.61], c='tab:red', linestyle='--',linewidth='1')
plt.ylim(-30,5)
plt.ylabel("Energy (kcal/mol)", size=12)
#plt.savefig('/home/teliu/work/aspp2/image/xiu/anova.png',bbox_inches='tight',transparent=True)
# Out:
# /home/teliu/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/teliu/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/teliu/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
import pandas as pd
import numpy as np
 
from scipy import stats
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
 
#这是观测值
A1 = [-7.25,-2.81,-5.98,-4.42,-4.65,-25.52,-15.95,-12.03,-9.16,-17.89,-4.16,-16.37,-11.86]
A2 = [-2.99,-12.38,-4.46,-2.59,-27.89,-7.69,-4.67,-6.47,-5.67,-6.47,-25.64]
 
data = [A1, A2]
# 方差的齐性检验
w, p = stats.levene(*data)
if p < 0.05:
    print('方差齐性假设不成立')
 
 
# 成立之后， 就可以进行单因素方差分析
f, p = stats.f_oneway(*data)
print(f, p)
# Out:
# 0.07949869431735872 0.7806132594272852

# %%
stats.levene(A1,A2)
# Out:
# LeveneResult(statistic=3.729127622741366e-05, pvalue=0.9951826589534798)

# %%
stats.ttest_ind(A1,A2,equal_var=True)
# Out:
# Ttest_indResult(statistic=-0.28195512819836915, pvalue=0.7806132594272848)

# %%
#aspp2

# %%
data1 = pd.DataFrame({"Simulation": s1, "Crystal": cry1})

# %%
plt.figure(dpi=300,figsize=(4,3))
colors=['tab:blue','tab:red']
sns.boxplot( data = data1,
           palette=colors,
           linewidth=1,
           showmeans=True,
            meanline=True,
            meanprops = {'linestyle':'--','color':'black'})
sns.stripplot( color = 'black',
              size = 7,
              alpha = 0.5,
              data = data1)
data_1=plt.plot([-0.5, 1.5], [-9.67, -9.67], c='tab:blue', linestyle='--',linewidth='1')
data_2=plt.plot([-0.5, 1.5], [-9.61, -9.61], c='tab:red', linestyle='--',linewidth='1')
plt.ylim(-30,5)
plt.ylabel("Energy (kcal/mol)", size=12)
#plt.savefig('/home/teliu/work/aspp2/figure/fig4/anova.png',bbox_inches='tight',transparent=True)
# Out:
# /home/teliu/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/teliu/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/teliu/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
stats.ttest_1samp(s1,-12.65)
# Out:
# Ttest_1sampResult(statistic=1.0798827894349963, pvalue=0.3014209990023838)

# %%
#iaspp

# %%
data2 = pd.DataFrame({"Simulation": s2, "Crystal": cry2})

# %%
plt.figure(dpi=300,figsize=(4,3))
colors=['tab:blue','tab:red']
sns.boxplot( data = data2,
           palette=colors,
           linewidth=1,
           showmeans=True,
            meanline=True,
            meanprops = {'linestyle':'--','color':'black'})
sns.stripplot( color = 'black',
              size = 7,
              alpha = 0.5,
              data = data2)
data_1=plt.plot([-0.5, 1.5], [-9.67, -9.67], c='tab:blue', linestyle='--',linewidth='1')
data_2=plt.plot([-0.5, 1.5], [-9.61, -9.61], c='tab:red', linestyle='--',linewidth='1')
plt.ylim(-30,5)
plt.ylabel("Energy (kcal/mol)", size=12)
#plt.savefig('/home/teliu/work/aspp2/figure/fig4/anova.png',bbox_inches='tight',transparent=True)
# Out:
# /home/teliu/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/teliu/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/teliu/miniconda3/lib/python3.9/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
#1ycs-aspp2  aspp2-martiniCG
stats.ttest_1samp(s1,-12.73)
# Out:
# Ttest_1sampResult(statistic=1.1224236265945569, pvalue=0.2836386878754473)

# %%
#1ycs-iaspp  iaspp-martiniCG
stats.ttest_1samp(s2,-22.17)
# Out:
# Ttest_1sampResult(statistic=4.670550632068722, pvalue=0.000880069166146333)

# %%
#6rz3-iaspp  iaspp-martiniCG
stats.ttest_1samp(s2,-7.57)
# Out:
# Ttest_1sampResult(statistic=-0.806560952525924, pvalue=0.438680424617928)

# %%
#aspp2-exp  aspp2-martiniCG
stats.ttest_1samp(s1,-9.67)
# Out:
# Ttest_1sampResult(statistic=-0.5047633947586312, pvalue=0.6228661365336867)

# %%
#iaspp-exp  iaspp-martiniCG
stats.ttest_1samp(s2,-9.61)
# Out:
# Ttest_1sampResult(statistic=-0.04126590919900121, pvalue=0.967896199925445)

# %%
#aspp2-exp  1ycs-aspp2
stats.ttest_1samp(-9.67,-12.73)
# Out:
# /tmp/ipykernel_57665/1386759397.py:2: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   stats.ttest_1samp(-9.67,-12.73)
# Ttest_1sampResult(statistic=nan, pvalue=nan)

# %%
plt.figure(figsize=(7,3),dpi=300)
labels = ['ASPP2\nExp','ASPP2\n1YCS','ASPP2\nMartiniCG','iASPP\nExp','iASPP\n6RZ3','iASPP\n1YCS','iASPP\nMartiniCG']
width=0.5
datas1=[-9.67,-12.73,-10.62,-9.61,-7.57,-22.17,-9.72]
errs=[1.48,0.12,6.51,1.5,0.12,0.11,8.43]
colors=['tab:blue','blue','lightblue','firebrick','red','red','salmon']
#plt.ylabel('First Formation Time (ns)',fontsize=12)
barlist = plt.bar(labels,datas1,width,yerr=errs,capsize=5)
for i, j in enumerate(barlist):
    j.set_color(colors[i])
    plt.bar_label(barlist,padding=3,fontsize=10)
plt.ylim([-40,0])
plt.yticks(fontsize=12)
plt.ylabel('Binding Free Energy (kcal/mol)',fontsize=12)
#plt.title('Total Energy',fontsize=12)
#plt.savefig('/home/teliu/work/aspp2/image/xiu/total-energy.png',bbox_inches='tight',transparent=True)

# %%
from scipy.stats import ttest_ind_from_stats
n1=3
mean1=-9.67
std1=1.48
n2=3
mean2=-12.73
std2=0.12
tstat,pvalue = ttest_ind_from_stats(mean1,std1,n1,mean2,std2,n2)
pvalue
# Out:
# 0.023387913765289946

# %%
from scipy.stats import ttest_ind_from_stats
n1=3
mean1=-9.61
std1=1.5
n2=3
mean2=-7.57
std2=0.12
tstat,pvalue = ttest_ind_from_stats(mean1,std1,n1,mean2,std2,n2)
pvalue
# Out:
# 0.07867959974002584

# %%
from scipy.stats import ttest_ind_from_stats
n1=3
mean1=-9.61
std1=1.5
n2=3
mean2=-22.17
std2=0.12
tstat,pvalue = ttest_ind_from_stats(mean1,std1,n1,mean2,std2,n2)
pvalue
# Out:
# 0.0001330849330628403
