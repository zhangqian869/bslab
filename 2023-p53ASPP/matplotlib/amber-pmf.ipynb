# %%
import numpy as np
import matplotlib.pylab as plt

# %%
from matplotlib import rcParams

# %%
aspp2_pmf=np.loadtxt("/home/teliu/work/aspp2/amber/pmf/p53-aspp2-zn-pmf/output/result.dat")
iaspp_pmf=np.loadtxt("/home/teliu/work/aspp2/amber/pmf/p53-iaspp-zn-pmf/output/result.dat")

# %%
print(aspp2_pmf)
# Out:
# [[3.4241935e+01 4.2346310e+00 2.8171000e-02 3.5700000e-04 1.7000000e-05]
#  [3.4725806e+01 6.5531000e-01 1.5815000e-02 1.4629700e-01 3.8980000e-03]
#  [3.5209677e+01 0.0000000e+00 5.2170000e-03 4.4020000e-01 3.8560000e-03]
#  [3.5693548e+01 1.9292700e-01 7.1920000e-03 3.1827500e-01 3.8540000e-03]
#  [3.6177419e+01 1.0046200e+00 1.1900000e-02 8.1324000e-02 1.6260000e-03]
#  [3.6661290e+01 2.1626510e+00 1.6997000e-02 1.1609000e-02 3.3000000e-04]
#  [3.7145161e+01 3.4553220e+00 1.9827000e-02 1.3210000e-03 4.4000000e-05]
#  [3.7629032e+01 4.0688390e+00 2.4667000e-02 4.7100000e-04 1.9000000e-05]
#  [3.8112903e+01 4.9015490e+00 2.7090000e-02 1.1600000e-04 5.0000000e-06]
#  [3.8596774e+01 5.8272910e+00 2.9507000e-02 2.5000000e-05 1.0000000e-06]
#  [3.9080645e+01 6.9120520e+00 3.4526000e-02 4.0000000e-06 0.0000000e+00]
#  [3.9564516e+01 8.2411580e+00 3.7002000e-02 0.0000000e+00 0.0000000e+00]
#  [4.0048387e+01 9.4908760e+00 4.0337000e-02 0.0000000e+00 0.0000000e+00]
# ...

# %%
plt.figure(dpi=300,figsize=(4,2))
plt.plot(aspp2_pmf[:,0],aspp2_pmf[:,1],color='blue', label='p53-aspp2')
plt.ylim([0,20])
plt.legend(loc=1,fontsize=7)
plt.xlabel('RC ($\AA$)')
plt.ylabel('PMF (kcal/mol)')
#plt.savefig('/home/teliu/Pictures/p53/p53-aspp2-pmf1.png',bbox_inches='tight',transparent=True)
# Out:
# Text(0, 0.5, 'PMF (kcal/mol)')

# %%
plt.figure(dpi=300,figsize=(4,2))
plt.plot(iaspp_pmf[:,0],iaspp_pmf[:,1],color='blue', label='p53-iaspp')
plt.ylim([0,20])
plt.legend(loc=1,fontsize=7)
plt.xlabel('RC ($\AA$)')
plt.ylabel('PMF (kcal/mol)')
#plt.savefig('/home/teliu/Pictures/p53/p53iaspppmf.png',bbox_inches='tight')
# Out:
# Text(0, 0.5, 'PMF (kcal/mol)')

# %%
plt.figure(dpi=300,figsize=(4,2))
plt.plot(aspp2_pmf[:,0]-34,aspp2_pmf[:,1],color='tab:blue', label='ASPP2',lw=0.5)
plt.errorbar(aspp2_pmf[:,0]-34,aspp2_pmf[:,1],yerr=aspp2_pmf[:,2],elinewidth=0.5,capsize=3,capthick=0.3,lw=0,color='black')
#plt.fill_between(aspp2_pmf[:,0]-34,aspp2_pmf[:,1]-aspp2_pmf[:,2],aspp2_pmf[:,1]+aspp2_pmf[:,2],color='blue',alpha=0.3,lw=1.5)
plt.plot(iaspp_pmf[:,0]-25,iaspp_pmf[:,1],color='tab:red', label='iASPP',lw=0.5)
plt.errorbar(iaspp_pmf[:,0]-25,iaspp_pmf[:,1],yerr=iaspp_pmf[:,2],elinewidth=0.5,capsize=3,capthick=0.3,lw=0,color='black')
#plt.fill_between(iaspp_pmf[:,0]-26,iaspp_pmf[:,1]-iaspp_pmf[:,2],iaspp_pmf[:,1]+iaspp_pmf[:,2],color='red',alpha=0.3,lw=1.5)
plt.ylim([0,20])
data_1=plt.plot([0, 15], [9.67, 9.67], c='tab:blue', linestyle='--',linewidth='0.5')
data_2=plt.plot([0, 15], [9.61, 9.61], c='tab:red', linestyle='--',linewidth='0.5')
plt.xticks(np.arange(0,20,5))
plt.yticks(np.arange(0,25,5))
plt.legend(loc=1,fontsize=8)
plt.xlabel('RC ($\AA$)')
plt.ylabel('PMF (kcal/mol)',fontsize=7,labelpad=2)
plt.yticks(fontsize=7)
plt.xticks(fontsize=7)
bwith = 0.4 #边框宽度设置为2
ax = plt.gca()#获取边框
ax.spines['bottom'].set_linewidth(bwith)
ax.spines['left'].set_linewidth(bwith)
ax.spines['top'].set_linewidth(bwith)
ax.spines['right'].set_linewidth(bwith)
#plt.savefig('/home/teliu/work/aspp2/image/xiu/amber-pmf.png',bbox_inches='tight',transparent=True)

# %%
plt.figure(dpi=300,figsize=(4,2))
plt.plot(aspp2_pmf[:,0]-34,aspp2_pmf[:,1],color='b', label='p53-ASPP2',lw=0.5)
plt.errorbar(aspp2_pmf[:,0]-34,aspp2_pmf[:,1],yerr=aspp2_pmf[:,2],elinewidth=2,capsize=3,capthick=0.3,lw=0.5,color='b')
#plt.fill_between(aspp2_pmf[:,0]-34,aspp2_pmf[:,1]-aspp2_pmf[:,2],aspp2_pmf[:,1]+aspp2_pmf[:,2],color='blue',alpha=0.3,lw=1.5)
plt.plot(iaspp_pmf[:,0]-26,iaspp_pmf[:,1],color='r', label='p53-iASPP',lw=0.5)
plt.errorbar(iaspp_pmf[:,0]-26,iaspp_pmf[:,1],yerr=iaspp_pmf[:,2],elinewidth=2,capsize=3,capthick=0.3,lw=0.5,color='r')
#plt.fill_between(iaspp_pmf[:,0]-26,iaspp_pmf[:,1]-iaspp_pmf[:,2],iaspp_pmf[:,1]+iaspp_pmf[:,2],color='red',alpha=0.3,lw=1.5)
plt.ylim([0,20])
plt.grid(False)
data_1=plt.plot([0, 15], [9.67, 9.67], c='b', linestyle='--',linewidth='0.5')
data_2=plt.plot([0, 15], [9.61, 9.61], c='red', linestyle='--',linewidth='0.5')
plt.legend(loc=1,fontsize=6)
plt.xlabel('RC ($\AA$)')
plt.ylabel('PMF (kcal/mol)')
#plt.savefig('/home/teliu/work/aspp2/image/p53-iaspp2-pmf.png',bbox_inches='tight',transparent=True)
# Out:
# Text(0, 0.5, 'PMF (kcal/mol)')

# %%
plt.figure(dpi=300,figsize=(4,2))
nozn=np.loadtxt("/home/teliu/work/aspp2/amber/pmf/p53-aspp2-pmf/output/result.dat")
zn=np.loadtxt("/home/teliu/work/aspp2/amber/pmf/p53-aspp2-zn-pmf/output/result.dat")
plt.plot(nozn[:,0]-34,nozn[:,1],color='red', label='p53-ASPP2 without ZN',lw=0.5)
plt.errorbar(nozn[:,0]-34,nozn[:,1],yerr=nozn[:,2],elinewidth=0.5,capsize=3,capthick=0.3,lw=0,color='black')
#plt.fill_between(nozn[:,0]-34,nozn[:,1]-nozn[:,2],nozn[:,1]+nozn[:,2],color='red',alpha=0.3,lw=1.5)
plt.plot(zn[:,0]-34,zn[:,1],color='blue', label='p53-ASPP2 with ZN',lw=0.5)
plt.errorbar(zn[:,0]-34,zn[:,1],yerr=zn[:,2],elinewidth=0.5,capsize=3,capthick=0.3,lw=0,color='black')
#plt.fill_between(zn[:,0]-34,zn[:,1]-zn[:,2],zn[:,1]+zn[:,2],color='blue',alpha=0.3,lw=1.5)
data_1=plt.plot([0, 15], [9.67, 9.67], c='b', linestyle='--',linewidth='0.5')
plt.ylim([0,25])
plt.legend(loc=1,fontsize=7)
plt.xlabel('RC ($\AA$)')
plt.ylabel('PMF (kcal/mol)')
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)
#plt.savefig('/home/teliu/work/aspp2/image/xiu/p53-aspp2-znnoznpmf1.png',bbox_inches='tight',transparent=True)
# Out:
# (array([-2.5,  0. ,  2.5,  5. ,  7.5, 10. , 12.5, 15. , 17.5]),
#  [Text(-2.5, 0, '−2.5'),
#   Text(0.0, 0, '0.0'),
#   Text(2.5, 0, '2.5'),
#   Text(5.0, 0, '5.0'),
#   Text(7.5, 0, '7.5'),
#   Text(10.0, 0, '10.0'),
#   Text(12.5, 0, '12.5'),
#   Text(15.0, 0, '15.0'),
#   Text(17.5, 0, '17.5')])

# %%
plt.figure(dpi=300,figsize=(4,2))
nozn=np.loadtxt("/home/teliu/work/aspp2/amber/pmf/p53-iaspp-zn-pmf/output/result.dat")
zn=np.loadtxt("/home/teliu/work/aspp2/amber/pmf/p53-iaspp-1ycs-zn-pmf/output/result.dat")
plt.plot(nozn[:,0]-25,nozn[:,1],color='red', label='p53-iASPP-6RZ3',lw=0.5)
plt.errorbar(nozn[:,0]-25,nozn[:,1],yerr=nozn[:,2],elinewidth=0.5,capsize=3,capthick=0.3,lw=0,color='black')
#plt.fill_between(nozn[:,0]-26,nozn[:,1]-nozn[:,2],nozn[:,1]+nozn[:,2],color='red',alpha=0.3,lw=1.5)
plt.plot(zn[:,0]-34.5,zn[:,1],color='blue', label='p53-iASPP-1YCS',lw=0.5)
plt.errorbar(zn[:,0]-34.5,zn[:,1],yerr=zn[:,2],elinewidth=0.5,capsize=3,capthick=0.3,lw=0,color='black')
#plt.fill_between(zn[:,0]-37,zn[:,1]-zn[:,2],zn[:,1]+zn[:,2],color='blue',alpha=0.3,lw=1.5)
data_2=plt.plot([0, 15], [9.61, 9.61], c='red', linestyle='--',linewidth='0.5')
plt.ylim([0,30])
plt.legend(loc=0,fontsize=7)
plt.xlabel('RC ($\AA$)')
plt.ylabel('PMF (kcal/mol)')
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)
#plt.savefig('/home/teliu/work/aspp2/image/xiu/p53-iaspp-1ycs6rz3-pmf.png',bbox_inches='tight',transparent=True)

# %%
plt.figure(dpi=300,figsize=(4,2))
nozn=np.loadtxt("/home/teliu/work/aspp2/amber/pmf/p53-iaspp-2-pmf/output/result.dat")
zn=np.loadtxt("/home/teliu/work/aspp2/amber/pmf/p53-iaspp-zn-pmf/output/result.dat")
plt.plot(nozn[:,0]-26,nozn[:,1],color='red', label='p53-iASPP without ZN',lw=0.5)
plt.errorbar(nozn[:,0]-26,nozn[:,1],yerr=nozn[:,2],elinewidth=0.5,capsize=3,capthick=0.3,lw=0,color='black')
#plt.fill_between(nozn[:,0]-26,nozn[:,1]-nozn[:,2],nozn[:,1]+nozn[:,2],color='red',alpha=0.3,lw=1.5)
plt.plot(zn[:,0]-25,zn[:,1],color='blue', label='p53-iASPP with ZN',lw=0.5)
plt.errorbar(zn[:,0]-25,zn[:,1],yerr=zn[:,2],elinewidth=0.5,capsize=3,capthick=0.3,lw=0,color='black')
#plt.fill_between(zn[:,0]-26,zn[:,1]-zn[:,2],zn[:,1]+zn[:,2],color='blue',alpha=0.3,lw=1.5)
data_2=plt.plot([0, 15], [9.61, 9.61], c='red', linestyle='--',linewidth='0.5')
plt.ylim([0,25])
plt.legend(loc=1,fontsize=7)
plt.xlabel('RC ($\AA$)')
plt.ylabel('PMF (kcal/mol)')
plt.yticks(fontsize=10)
plt.xticks(fontsize=10)
#plt.savefig('/home/teliu/work/aspp2/image/xiu/p53-iaspp-znnozn-pmf.png',bbox_inches='tight',transparent=True)

# %%
plt.figure(dpi=300,figsize=(4,2))
nozn=np.loadtxt("/home/teliu/work/pmf/p53-iaspp-1ycs-pmf/output/result2.dat")
zn=np.loadtxt("/home/teliu/work/pmf/p53-iaspp-1ycs-zn-pmf/output/results.dat")
plt.plot(nozn[:,0],nozn[:,1],color='red', label='iASPP-noZN')
plt.plot(zn[:,0],zn[:,1],color='blue', label='iASPP-ZN')
plt.ylim([0,30])
plt.legend(loc=1,fontsize=7)
plt.xlabel('RC ($\AA$)')
plt.ylabel('PMF (kcal/mol)')
#plt.savefig('/home/teliu/work/p53/p53-iaspp-1ycs-znnozn-pmf.png',bbox_inches='tight',transparent=True)

# %%
plt.figure(dpi=300,figsize=(4,3))
x = np.array([0,20])
y = np.array([0,20])
plt.xlim([0,20])
plt.ylim([0,20])
datax1 = np.array([10.41,10.41,10.41,10.41])
datay1 = np.array([20.0,17.5,15.0,8.2])

datax2 = np.array([10.48,10.48])
datay2 = np.array([11.5,12.5])
plt.xlabel('Experimental Data',fontsize=14)
plt.ylabel('PMF',fontsize=14)
plt.xticks(np.arange(0,25,5))
plt.yticks(np.arange(0,25,5))
#plt.title('scatter example')

plt.plot(x, y, 'k--',linewidth = '0.5')

plt.scatter(datax1, datay1,color='b',marker='o',s=5)
plt.scatter(datax2, datay2,color='r',marker='o',s=5)

#plt.show()

plt.savefig('/home/teliu/work/1amber/p53/p53-image/pmf-experimentaldata.png',bbox_inches='tight',transparent=True)
#plt.savefig('/home/teliu/work/1amber/p53/p53-image/testpmf.png')

# %%
plt.figure(dpi=300,figsize=(4,2))
nozn=np.loadtxt("/home/teliu/work/1amber/p53/pmf/temp/c1-1/output/result.dat")
plt.plot(nozn[:,0],nozn[:,1],color='blue')
#plt.ylim([0,30])
#plt.legend(loc=1,fontsize=7)
plt.xlabel('RC ($\AA$)')
plt.ylabel('PMF (kcal/mol)')
plt.savefig('/home/teliu/work/2martini/p53/image/c1-1-pmf.png',bbox_inches='tight',transparent=True)
