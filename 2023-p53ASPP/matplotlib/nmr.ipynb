# %%
import matplotlib.pylab as plt

import numpy as np

# %%
import os

# %%
def readData(indx):
    """
    read in every contact file
    """
    
    rootdir1="/home/teliu/work/aspp2/martini/temp/pp53-aspp2/result/con/"
    file1 = os.path.join(rootdir1,"time"+str(indx)+".dat")
    data1 = np.loadtxt(file1)
    
    return data1

# %%
a1=np.loadtxt("/home/teliu/work/aspp2/martini/temp/pp53-aspp2/result/con/time31.dat")

# %%
np.set_printoptions(suppress=True)

# %%
datapoints =np.linspace(1,10,500)

# %%
alldata1 = [readData(i) for i in np.arange(1,50)]

# %%
mean1=np.mean(alldata1,axis=0)

# %%
print(mean1)
# Out:
# [[233.          22.16326531]
#  [234.          16.3877551 ]
#  [235.          18.85714286]
#  [236.          13.3877551 ]
#  [237.           2.59183673]
#  [238.           6.51020408]
#  [239.          10.73469388]
#  [240.           4.20408163]
#  [241.           1.73469388]
#  [242.           8.81632653]
#  [243.          14.18367347]
#  [244.          12.57142857]
#  [245.          10.97959184]
#  [246.          17.46938776]
#  [247.          24.30612245]
#  [248.          16.32653061]
#  [249.           8.06122449]
#  [250.          22.51020408]
#  [251.          24.97959184]
#  [252.          15.97959184]
#  [253.          18.08163265]
#  [254.          33.55102041]
#  [255.          27.28571429]
#  [256.          23.65306122]
#  [257.          34.75510204]
#  [258.          32.69387755]
#  [259.          21.6122449 ]
#  [260.          24.28571429]
#  [261.          14.83673469]
#  [262.          16.51020408]
#  [263.          25.67346939]
#  [264.          32.10204082]
# ...

# %%
def readData(indx):
    """
    read in every contact file
    """
    
    rootdir2="/home/teliu/work/aspp2/martini/p53/p53-aspp2/result/con/"
    file2 = os.path.join(rootdir2,"time"+str(indx)+".dat")
    data2 = np.loadtxt(file2)
    
    return data2

# %%
datapoints =np.linspace(1,10,500)

# %%
alldata2 = [readData(i) for i in np.arange(1,50)]

# %%
mean2=np.mean(alldata2,axis=0)

# %%
print(mean2)
# Out:
# [[192.           5.57142857]
#  [193.           3.65306122]
#  [194.           5.42857143]
#  [195.           3.10204082]
#  [196.           0.34693878]
#  [197.           1.7755102 ]
#  [198.           4.44897959]
#  [199.           1.81632653]
#  [200.           0.53061224]
#  [201.           4.26530612]
#  [202.           7.57142857]
#  [203.           6.04081633]
#  [204.           4.34693878]
#  [205.           6.02040816]
#  [206.           8.14285714]
#  [207.           3.40816327]
#  [208.           0.59183673]
#  [209.           4.83673469]
#  [210.           5.28571429]
#  [211.           2.06122449]
#  [212.           3.08163265]
#  [213.          10.28571429]
#  [214.           8.10204082]
#  [215.           7.28571429]
#  [216.          12.42857143]
#  [217.          11.51020408]
#  [218.           6.44897959]
#  [219.           8.89795918]
#  [220.           4.04081633]
#  [221.           4.95918367]
#  [222.          11.32653061]
#  [223.          16.26530612]
# ...

# %%
plt.figure(figsize=(6,4),dpi=500)
plt.bar(mean2[:,0]+465,mean2[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='Martini',color='r')
plt.bar(mean1[:,0]+424,mean1[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='Martini',color='b')
#plt.bar(imapnmr[:,0],imapnmr[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='NMR')
#plt.ylim([0,0.25])
plt.legend(loc=1,fontsize=7)
plt.title('p53-iASPP')
plt.xlabel('Residues')
plt.ylabel('Contact Probability')
#plt.yticks(np.arange(0,0.3,0.05))
#plt.savefig('/home/teliu/work/aspp2/image//iaspp-nmr.png',bbox_inches='tight',transparent=True)
# Out:
# Text(0, 0.5, 'Contact Probability')

# %%
plt.figure(figsize=(6,4),dpi=500)
plt.bar(mean1[:,0]+465,mean1[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='Martini',color='r')
#plt.bar(imapnmr[:,0],imapnmr[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='NMR')
#plt.ylim([0,0.25])
plt.legend(loc=1,fontsize=7)
plt.title('p53-iASPP')
plt.xlabel('Residues')
plt.ylabel('Contact Probability')
#plt.yticks(np.arange(0,0.3,0.05))
#plt.savefig('/home/teliu/work/aspp2/image//iaspp-nmr.png',bbox_inches='tight',transparent=True)
# Out:
# Text(0, 0.5, 'Contact Probability')

# %%
def readData(indx):
    """
    read in every contact file
    """
    
    rootdir3="/home/teliu/work/aspp2/martini/temp/pp53-aspp2/result/con/test/"
    file3 = os.path.join(rootdir3,"time"+str(indx)+".dat")
    data3 = np.loadtxt(file3)
    
    return data3

# %%
alldata3 = [readData(i) for i in np.arange(1,50)]

# %%
mean3=np.mean(alldata3,axis=0)

# %%
print(mean3)
# Out:
# [[  1.          45.55102041]
#  [  2.          41.3877551 ]
#  [  3.          42.83673469]
#  [  4.          45.12244898]
#  [  5.          44.32653061]
#  [  6.          36.75510204]
#  [  7.          37.73469388]
#  [  8.          49.63265306]
#  [  9.          46.46938776]
#  [ 10.          44.59183673]
#  [ 11.          46.2244898 ]
#  [ 12.          47.06122449]
#  [ 13.          43.14285714]
#  [ 14.          50.81632653]
#  [ 15.          53.30612245]
#  [ 16.          53.91836735]
#  [ 17.          54.75510204]
#  [ 18.          57.12244898]
#  [ 19.          59.24489796]
#  [ 20.          59.18367347]
#  [ 21.          58.71428571]
#  [ 22.          59.20408163]
#  [ 23.          61.04081633]
#  [ 24.          61.67346939]
#  [ 25.          61.6122449 ]
#  [ 26.          61.91836735]
#  [ 27.          61.36734694]
#  [ 28.          59.53061224]
#  [ 29.          58.10204082]
#  [ 30.          54.95918367]
#  [ 31.          53.51020408]
#  [ 32.          49.93877551]
# ...

# %%
def readData(indx):
    """
    read in every contact file
    """
    
    rootdir4="/home/teliu/work/aspp2/martini/p53/p53-aspp2/result/con/test/"
    file4 = os.path.join(rootdir4,"time"+str(indx)+".dat")
    data4 = np.loadtxt(file4)
    
    return data4

# %%
alldata4 = [readData(i) for i in np.arange(1,50)]

# %%
mean4=np.mean(alldata4,axis=0)

# %%
print(mean4)
# Out:
# [[  1.          10.10204082]
#  [  2.           5.36734694]
#  [  3.           4.97959184]
#  [  4.           3.7755102 ]
#  [  5.           5.93877551]
#  [  6.           6.12244898]
#  [  7.           3.16326531]
#  [  8.           3.63265306]
#  [  9.           7.24489796]
#  [ 10.           9.30612245]
#  [ 11.           3.95918367]
#  [ 12.           2.87755102]
#  [ 13.           0.83673469]
#  [ 14.           0.79591837]
#  [ 15.           0.79591837]
#  [ 16.           1.91836735]
#  [ 17.           3.48979592]
#  [ 18.           8.20408163]
#  [ 19.          14.2244898 ]
#  [ 20.          10.67346939]
#  [ 21.           9.40816327]
#  [ 22.           7.46938776]
#  [ 23.          14.32653061]
#  [ 24.          17.85714286]
#  [ 25.          20.63265306]
#  [ 26.           9.65306122]
#  [ 27.           5.42857143]
#  [ 28.           2.18367347]
#  [ 29.           0.08163265]
#  [ 30.           0.14285714]
#  [ 31.           0.6122449 ]
#  [ 32.           3.51020408]
# ...

# %%
plt.figure(figsize=(6,4),dpi=500)
plt.bar(mean3[:,0],mean3[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='pp53-aspp2',color='r')
plt.bar(mean4[:,0]+41,mean4[:,1],edgecolor='black',linewidth=0.5,width=1,alpha=0.4,label='p53-aspp2',color='b')
plt.legend(loc=1)

# %%
imapnmr=np.loadtxt('/home/teliu/work/aspp2/martini/p53/p53-iaspp/result/rmsd-dis/contact7/nmr.dat',comments="#")
amapnmr=np.loadtxt('/home/teliu/work/aspp2/martini/p53/p53-aspp2/result/dis-rmsd/contact7/nmr.dat',comments="#")
pp53aspp2=np.loadtxt('/home/teliu/work/aspp2/martini/temp/pp53-aspp2/result/dis-rmsd/contact/test/times.dat',comments="#")
pp53iaspp=np.loadtxt('/home/teliu/work/aspp2/martini/temp/pp53-iaspp/result/dis-rmsd/contact/test/times.dat',comments="#")

# %%
#pp53-aspp2
fig,ax=plt.subplots(1,1,figsize=(3,2),dpi=300)
ax.bar(amapnmr[:,0],amapnmr[:,1],linewidth=0.15,edgecolor='black',width=1,alpha=1,label='NMR',color='skyblue')
ax.set_ylabel('Chemical Shift Change')
ax.set_ylim(0,0.25)
ax.set_xticks(range(925,1145,20))
ax.set_xticklabels(range(925,1145,20),fontsize=6,rotation=30) 

ax2 = ax.twinx() 
ax.bar(pp53aspp2[:,0]+695,pp53aspp2[:,1]/500,edgecolor='black',linewidth=0.15,width=1,alpha=0.6,label='Martini',color='darkorange')
ax2.set_ylabel('Normal Contact')
ax2.set_ylim(0,0.25)

ax.legend(loc=1,fontsize=5)
plt.title('pp53-ASPP2')
plt.xlabel('Residues')
#plt.savefig('/home/teliu/work/aspp2/figure/fig3/aspp2-con-nmr.png',bbox_inches='tight',transparent=True)

# %%
#p53-iaspp
fig,ax=plt.subplots(1,1,figsize=(3,2),dpi=300)
ax.bar(imapnmr[:,0],imapnmr[:,1],edgecolor='black',linewidth=0.15,width=1,alpha=1,label='NMR',color='skyblue')
ax.set_ylabel('Chemical Shift Change')
ax.set_ylim(0,0.25)
ax.set_xticks(range(625,845,20))
ax.set_xticklabels(range(625,845,20),fontsize=6,rotation=30)

ax2 = ax.twinx()
ax.bar(pp53iaspp[:,0]+424,pp53iaspp[:,1]/500,edgecolor='black',linewidth=0.15,width=1,alpha=0.6,label='Martini',color='darkorange')
plt.ylim(0,0.25)
ax2.set_ylabel('Normal Contact')
ax2.set_ylim(0,0.25)

ax.legend(loc=1,fontsize=5)
plt.title('pp53-iASPP')
#plt.savefig('/home/teliu/work/aspp2/figure/fig3/iaspp-con-nmr.png',bbox_inches='tight',transparent=True)

# %%
print(pp53iaspp[:,1]/1000)
# Out:
# [0.014 0.019 0.019 0.006 0.008 0.009 0.024 0.    0.001 0.011 0.001 0.
#  0.022 0.038 0.018 0.017 0.039 0.081 0.017 0.001 0.031 0.042 0.009 0.003
#  0.058 0.04  0.006 0.004 0.003 0.    0.003 0.004 0.009 0.003 0.046 0.035
#  0.005 0.    0.    0.    0.    0.    0.002 0.    0.    0.015 0.01  0.004
#  0.006 0.033 0.064 0.006 0.001 0.044 0.038 0.    0.    0.036 0.003 0.
#  0.    0.    0.    0.003 0.004 0.033 0.026 0.083 0.107 0.09  0.071 0.016
#  0.01  0.    0.    0.018 0.02  0.009 0.019 0.028 0.054 0.017 0.019 0.02
#  0.007 0.038 0.054 0.01  0.002 0.055 0.043 0.004 0.013 0.046 0.02  0.001
#  0.021 0.03  0.    0.001 0.037 0.077 0.1   0.058 0.003 0.006 0.001 0.
#  0.    0.002 0.007 0.032 0.018 0.052 0.05  0.085 0.045 0.021 0.006 0.
#  0.    0.002 0.002 0.001 0.001 0.001 0.001 0.009 0.002 0.002 0.    0.003
#  0.002 0.004 0.019 0.008 0.022 0.054 0.028 0.037 0.031 0.003 0.    0.001
#  0.    0.001 0.    0.022 0.014 0.    0.003 0.002 0.    0.    0.004 0.004
# ...

# %%
print(pp53iaspp[:,1])
# Out:
# [ 14.  19.  19.   6.   8.   9.  24.   0.   1.  11.   1.   0.  22.  38.
#   18.  17.  39.  81.  17.   1.  31.  42.   9.   3.  58.  40.   6.   4.
#    3.   0.   3.   4.   9.   3.  46.  35.   5.   0.   0.   0.   0.   0.
#    2.   0.   0.  15.  10.   4.   6.  33.  64.   6.   1.  44.  38.   0.
#    0.  36.   3.   0.   0.   0.   0.   3.   4.  33.  26.  83. 107.  90.
#   71.  16.  10.   0.   0.  18.  20.   9.  19.  28.  54.  17.  19.  20.
#    7.  38.  54.  10.   2.  55.  43.   4.  13.  46.  20.   1.  21.  30.
#    0.   1.  37.  77. 100.  58.   3.   6.   1.   0.   0.   2.   7.  32.
#   18.  52.  50.  85.  45.  21.   6.   0.   0.   2.   2.   1.   1.   1.
#    1.   9.   2.   2.   0.   3.   2.   4.  19.   8.  22.  54.  28.  37.
#   31.   3.   0.   1.   0.   1.   0.  22.  14.   0.   3.   2.   0.   0.
#    4.   4.   8.   2.   0.   0.   2.   3.   8.   6.   6.  28.  31.]
