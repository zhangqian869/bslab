# %%
import matplotlib.pylab as plt
import numpy as np

# %%
data1 = np.loadtxt("/home/teliu/work/aspp2/martini/temp/pp53l-aspp2/result/stable/nonnative.c0_map",comments="#")
data2 = np.loadtxt("/home/teliu/work/aspp2/martini/temp/pp53l-iaspp/result/stable/nonnative.c0_map",comments="#")

# %%
data11 = data1.reshape((460,461))

# %%
data22 = data2.reshape((434,435))

# %%
plt.figure(figsize=(10,4))
plt.pcolormesh(data11,vmax=0.002)
plt.xlim([1,267])
plt.ylim([267,460])
plt.xticks(np.arange(1,267,20))
plt.yticks(np.arange(268,460,20))
plt.title('pp53l-ASPP2')
fcb = plt.colorbar(plt.cm.ScalarMappable())
#plt.savefig('/home/teliu/work/aspp2/image/contact/p53l-ASPP2.png',bbox_inches='tight',transparent=True)
# Out:
# /tmp/ipykernel_498454/3004229000.py:8: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   fcb = plt.colorbar(plt.cm.ScalarMappable())

# %%
plt.figure(figsize=(10,3))
plt.pcolormesh(data22,vmax=0.002)
plt.xlim([1,267])
plt.ylim([268,434])
plt.xticks(np.arange(1,267,20))
plt.yticks(np.arange(268,434,20))
plt.title('pp53l-iASPP')
fcb = plt.colorbar(plt.cm.ScalarMappable())
#plt.savefig('/home/teliu/work/aspp2/image/contact/pp53l-iASPP.png',bbox_inches='tight',transparent=True)
# Out:
# /tmp/ipykernel_498454/1230120214.py:8: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   fcb = plt.colorbar(plt.cm.ScalarMappable())
